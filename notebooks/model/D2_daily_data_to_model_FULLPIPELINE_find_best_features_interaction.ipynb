# %% [markdown]
# # Notebook used to help create:
#
# - importing data src
# - precprocessing data src

# %%
# %pwd
# Out:
# 'C:\\Users\\bjk1y13\\OneDrive - University of Southampton\\MH028_UHS_Weather\\4_Analysis\\EDclassification\\notebooks\\model'

# %%
import pandas as pd
import numpy as np
from src.data.io import import_pickled_feature_dfs, import_merge_prevday_target_column, import_merge_pickled_target_class

# %% [markdown]
# # Import data

# %%
features = import_pickled_feature_dfs('../../data/interim/D2_timeseries/', ['EDdaily.pkl', 'IPdaily.pkl', 'callender.pkl'])

# %%
features.shape
# Out:
# (2465, 13)

# %%
features.tail()
# Out:
#            EDDAILYattendances EDDAILYadmissions EDDAILYage_mean  \
#
# 2018-09-26                446               182         42.9126
# 2018-09-27                487               188         44.7064
# 2018-09-28                482               168         44.1992
# 2018-09-29                463               191         46.4989
# 2018-09-30                367               157         40.3597
#
#            EDDAILYage_75plus IPDAILYpatients_total IPDAILYpatients_nonelec  \
#
# 2018-09-26                62                     2                       1
# 2018-09-27                82                     2                       1
# 2018-09-28                74                     2                       1
# 2018-09-29                84                     1                       0
# 2018-09-30                47                     1                       0
#
#            IPDAILYpatients_elec IPDAILYpatients_daycase  \
#
# 2018-09-26                    1                       0
# 2018-09-27                    1                       0
# 2018-09-28                    1                       0
# 2018-09-29                    1                       0
# 2018-09-30                    1                       0
#
#            IPDAILYage_mean_elecnonelec IPDAILYage_75plus_elecnonelec  year  \
#
# 2018-09-26                        35.5                             0  2018
# 2018-09-27                        35.5                             0  2018
# 2018-09-28                        35.5                             0  2018
# 2018-09-29                           0                             0  2018
# 2018-09-30                           0                             0  2018
#
#             month  dayofweek
#
# 2018-09-26      9  Wednesday
# 2018-09-27      9   Thursday
# 2018-09-28      9     Friday
# 2018-09-29      9   Saturday
# 2018-09-30      9     Sunday

# %%
target = pd.read_pickle('../../data/interim/EDooc_class.pkl')

# %%
features = target.merge(features, right_index=True, left_index=True)

# %% [markdown]
# Remember target does not need to be offset because features were calculated for the previous days records

# %%
features_final = features.copy()
# features_final['flag_target'] = features_final['flag_target'].shift(-1)
##### we do shift the EDocc col as this is for the current date in index.
features_final['EDocc'] = features_final['EDocc'].shift(1)

# %%
features_final.rename(columns={'EDocc':'TARGET_prevday'},inplace=True)

# %%
features_final['flag_target_prevday'] = features_final['flag_target'].shift(1)

# %%
features_final.flag_target.value_counts()
# Out:
# 0    2094
# 1     371
# Name: flag_target, dtype: int64

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-01             NaN            1                NaN               NaN
# 2012-01-02       55.750000            0                377               151
# 2012-01-03       38.541667            0                350               139
# 2012-01-04       40.208333            0                356               125
# 2012-01-05       32.375000            0                284                92
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-01             NaN               NaN                   NaN
# 2012-01-02         40.0186                59                  1185
# 2012-01-03         42.2114                44                  1228
# 2012-01-04         45.1011                58                  1564
# 2012-01-05         42.5035                49                  1535
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-01                     NaN                  NaN
# 2012-01-02                    1001                  141
# 2012-01-03                    1037                  141
# 2012-01-04                    1074                  208
# 2012-01-05                    1066                  241
#
#            IPDAILYpatients_daycase IPDAILYage_mean_elecnonelec  \
# dt_date
# 2012-01-01                     NaN                         NaN
# 2012-01-02                      43                     57.3814
# 2012-01-03                      50                     57.4292
# 2012-01-04                     282                     55.5352
# 2012-01-05                     228                     55.4072
#
#            IPDAILYage_75plus_elecnonelec  year  month  dayofweek  \
# dt_date
# 2012-01-01                           NaN  2012      1     Sunday
# 2012-01-02                           441  2012      1     Monday
# 2012-01-03                           453  2012      1    Tuesday
# 2012-01-04                           475  2012      1  Wednesday
# 2012-01-05                           482  2012      1   Thursday
#
#             flag_target_prevday
# dt_date
# 2012-01-01                  NaN
# 2012-01-02                  1.0
# 2012-01-03                  0.0
# 2012-01-04                  0.0
# 2012-01-05                  0.0

# %%
#### add time feature
features_final['time'] = np.arange(0,len(features_final))

# %%
#### all inpatients who stay overnight
features_final['IPDAILYpatients_nonelec_elec'] = features_final['IPDAILYpatients_nonelec'] + features_final['IPDAILYpatients_elec']

# %%
#### interaction features
features_final['EDDAILYINT_atten_ip'] = features_final['EDDAILYattendances']*features_final['IPDAILYpatients_nonelec_elec']

features_final['EDDAILYINT_adm_ipage'] = features_final['EDDAILYadmissions']*features_final['IPDAILYage_75plus_elecnonelec']

# %%
features_final.columns
# Out:
# Index(['TARGET_prevday', 'flag_target', 'EDDAILYattendances',
#        'EDDAILYadmissions', 'EDDAILYage_mean', 'EDDAILYage_75plus',
#        'IPDAILYpatients_total', 'IPDAILYpatients_nonelec',
#        'IPDAILYpatients_elec', 'IPDAILYpatients_daycase',
#        'IPDAILYage_mean_elecnonelec', 'IPDAILYage_75plus_elecnonelec', 'year',
#        'month', 'dayofweek', 'flag_target_prevday', 'time',
#        'IPDAILYpatients_nonelec_elec', 'EDDAILYINT_atten_ip',
#        'EDDAILYINT_adm_ipage'],
#       dtype='object')

# %% [markdown]
# IP occ data after 2018-5-31 is not valid. NOTE: must check if that is same in RAW.

# %% [markdown]
# ## Add new lagged and derivative features

# %%
from src.features.feature_gen import create_lagged_vars_list

features_final = create_lagged_vars_list(features_final, 'TARGET_prevday', [6,13,27])

# %%
from src.features.feature_gen import perform_deriv_cals_multiple_columns

# %%
lags_required = {
                'TARGET_prevday':[7,14,30],
                 'EDDAILYattendances':[7,14,30],
                'EDDAILYadmissions':[7,14,30],
                 'EDDAILYage_mean':[7,14,30],
                'EDDAILYage_75plus':[7,14,30],
                 'IPDAILYpatients_total':[7,14,30],
                 'IPDAILYpatients_nonelec':[7,14,30],
                 'IPDAILYpatients_elec':[7,14,30],
                 'IPDAILYpatients_daycase':[7,14,30],
                 'IPDAILYage_mean_elecnonelec':[7,14,30],
                 'IPDAILYage_75plus_elecnonelec':[7,14,30],
                'EDDAILYINT_atten_ip':[7,14,30],
                'EDDAILYINT_adm_ipage':[7,14,30],
                 
                
                }
features_final = perform_deriv_cals_multiple_columns(features_final, lags_required, 2)

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-01             NaN            1                NaN               NaN
# 2012-01-02       55.750000            0                377               151
# 2012-01-03       38.541667            0                350               139
# 2012-01-04       40.208333            0                356               125
# 2012-01-05       32.375000            0                284                92
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-01             NaN               NaN                   NaN
# 2012-01-02         40.0186                59                  1185
# 2012-01-03         42.2114                44                  1228
# 2012-01-04         45.1011                58                  1564
# 2012-01-05         42.5035                49                  1535
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-01                     NaN                  NaN
# 2012-01-02                    1001                  141
# 2012-01-03                    1037                  141
# 2012-01-04                    1074                  208
# 2012-01-05                    1066                  241
#
#            IPDAILYpatients_daycase  ... EDDAILYINT_atten_ip_deriv1_lag14  \
# dt_date                             ...
# 2012-01-01                     NaN  ...                         -54810.0
# 2012-01-02                      43  ...                         -54810.0
# 2012-01-03                      50  ...                         -54810.0
# 2012-01-04                     282  ...                         -54810.0
# 2012-01-05                     228  ...                         -54810.0
#
#            EDDAILYINT_atten_ip_deriv2_lag14  EDDAILYINT_atten_ip_deriv1_lag30  \
# dt_date
# 2012-01-01                          61484.0                           46199.0
# 2012-01-02                          61484.0                           46199.0
# 2012-01-03                          61484.0                           46199.0
# 2012-01-04                          61484.0                           46199.0
# 2012-01-05                          61484.0                           46199.0
#
#             EDDAILYINT_atten_ip_deriv2_lag30 EDDAILYINT_adm_ipage_deriv1_lag7  \
# dt_date
# 2012-01-01                          -13343.0                          -3343.0
# 2012-01-02                          -13343.0                          -3343.0
# 2012-01-03                          -13343.0                          -3343.0
# 2012-01-04                          -13343.0                          -3343.0
# 2012-01-05                          -13343.0                          -3343.0
#
#             EDDAILYINT_adm_ipage_deriv2_lag7  \
# dt_date
# 2012-01-01                            3004.0
# 2012-01-02                            3004.0
# 2012-01-03                            3004.0
# 2012-01-04                            3004.0
# 2012-01-05                            3004.0
#
#             EDDAILYINT_adm_ipage_deriv1_lag14  \
# dt_date
# 2012-01-01                            -3682.0
# 2012-01-02                            -3682.0
# 2012-01-03                            -3682.0
# 2012-01-04                            -3682.0
# 2012-01-05                            -3682.0
#
#            EDDAILYINT_adm_ipage_deriv2_lag14  \
# dt_date
# 2012-01-01                           -1243.0
# 2012-01-02                           -1243.0
# 2012-01-03                           -1243.0
# 2012-01-04                           -1243.0
# 2012-01-05                           -1243.0
#
#            EDDAILYINT_adm_ipage_deriv1_lag30 EDDAILYINT_adm_ipage_deriv2_lag30
# dt_date
# 2012-01-01                            8226.0                          -22165.0
# 2012-01-02                            8226.0                          -22165.0
# 2012-01-03                            8226.0                          -22165.0
# 2012-01-04                            8226.0                          -22165.0
# 2012-01-05                            8226.0                          -22165.0
#
# [5 rows x 101 columns]

# %%
features_final.tail()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2018-09-26       53.541667            0                446               182
# 2018-09-27       59.791667            1                487               188
# 2018-09-28       63.250000            0                482               168
# 2018-09-29       56.541667            0                463               191
# 2018-09-30       44.125000            0                367               157
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2018-09-26         42.9126                62                     2
# 2018-09-27         44.7064                82                     2
# 2018-09-28         44.1992                74                     2
# 2018-09-29         46.4989                84                     1
# 2018-09-30         40.3597                47                     1
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2018-09-26                       1                    1
# 2018-09-27                       1                    1
# 2018-09-28                       1                    1
# 2018-09-29                       0                    1
# 2018-09-30                       0                    1
#
#            IPDAILYpatients_daycase  ... EDDAILYINT_atten_ip_deriv1_lag14  \
# dt_date                             ...
# 2018-09-26                       0  ...                          -4776.0
# 2018-09-27                       0  ...                          -3646.0
# 2018-09-28                       0  ...                          -3066.0
# 2018-09-29                       0  ...                          -2553.0
# 2018-09-30                       0  ...                          -2531.0
#
#            EDDAILYINT_atten_ip_deriv2_lag14  EDDAILYINT_atten_ip_deriv1_lag30  \
# dt_date
# 2018-09-26                          -2607.0                           -5772.0
# 2018-09-27                          -1066.0                           -5435.0
# 2018-09-28                           -168.0                           -6873.0
# 2018-09-29                           1567.0                           -6737.0
# 2018-09-30                           1611.0                           -6561.0
#
#             EDDAILYINT_atten_ip_deriv2_lag30 EDDAILYINT_adm_ipage_deriv1_lag7  \
# dt_date
# 2018-09-26                            3440.0                           -600.0
# 2018-09-27                            1988.0                           -406.0
# 2018-09-28                            -840.0                           -201.0
# 2018-09-29                            3087.0                              0.0
# 2018-09-30                            3395.0                              0.0
#
#             EDDAILYINT_adm_ipage_deriv2_lag7  \
# dt_date
# 2018-09-26                            -711.0
# 2018-09-27                            -260.0
# 2018-09-28                              39.0
# 2018-09-29                             450.0
# 2018-09-30                             468.0
#
#             EDDAILYINT_adm_ipage_deriv1_lag14  \
# dt_date
# 2018-09-26                             -489.0
# 2018-09-27                             -552.0
# 2018-09-28                             -441.0
# 2018-09-29                             -450.0
# 2018-09-30                             -468.0
#
#            EDDAILYINT_adm_ipage_deriv2_lag14  \
# dt_date
# 2018-09-26                            -174.0
# 2018-09-27                            -510.0
# 2018-09-28                            -324.0
# 2018-09-29                            -351.0
# 2018-09-30                            -396.0
#
#            EDDAILYINT_adm_ipage_deriv1_lag30 EDDAILYINT_adm_ipage_deriv2_lag30
# dt_date
# 2018-09-26                            -456.0                            1413.0
# 2018-09-27                            -656.0                             612.0
# 2018-09-28                            -804.0                             719.0
# 2018-09-29                            -594.0                            1295.0
# 2018-09-30                            -558.0                             710.0
#
# [5 rows x 101 columns]

# %% [markdown]
# ## check and remove nans

# %%
features_final.isnull().sum()
# Out:
# TARGET_prevday                                 1
# flag_target                                    0
# EDDAILYattendances                             1
# EDDAILYadmissions                              1
# EDDAILYage_mean                                1
# EDDAILYage_75plus                              1
# IPDAILYpatients_total                          1
# IPDAILYpatients_nonelec                        1
# IPDAILYpatients_elec                           1
# IPDAILYpatients_daycase                        1
# IPDAILYage_mean_elecnonelec                    1
# IPDAILYage_75plus_elecnonelec                  1
# year                                           0
# month                                          0
# dayofweek                                      0
# flag_target_prevday                            1
# time                                           0
# IPDAILYpatients_nonelec_elec                   1
# EDDAILYINT_atten_ip                            1
# EDDAILYINT_adm_ipage                           1
# TARGET_prevday_lag6                            7
# TARGET_prevday_lag13                          14
# TARGET_prevday_lag27                          28
# TARGET_prevday_deriv1_lag7                     0
# TARGET_prevday_deriv2_lag7                     0
# TARGET_prevday_deriv1_lag14                    0
# TARGET_prevday_deriv2_lag14                    0
# TARGET_prevday_deriv1_lag30                    0
# TARGET_prevday_deriv2_lag30                    0
# EDDAILYattendances_deriv1_lag7                 0
#                                               ..
# IPDAILYpatients_daycase_deriv1_lag7            0
# IPDAILYpatients_daycase_deriv2_lag7            0
# IPDAILYpatients_daycase_deriv1_lag14           0
# IPDAILYpatients_daycase_deriv2_lag14           0
# IPDAILYpatients_daycase_deriv1_lag30           0
# IPDAILYpatients_daycase_deriv2_lag30           0
# IPDAILYage_mean_elecnonelec_deriv1_lag7        0
# IPDAILYage_mean_elecnonelec_deriv2_lag7        0
# IPDAILYage_mean_elecnonelec_deriv1_lag14       0
# IPDAILYage_mean_elecnonelec_deriv2_lag14       0
# IPDAILYage_mean_elecnonelec_deriv1_lag30       0
# IPDAILYage_mean_elecnonelec_deriv2_lag30       0
# IPDAILYage_75plus_elecnonelec_deriv1_lag7      0
# IPDAILYage_75plus_elecnonelec_deriv2_lag7      0
# IPDAILYage_75plus_elecnonelec_deriv1_lag14     0
# IPDAILYage_75plus_elecnonelec_deriv2_lag14     0
# IPDAILYage_75plus_elecnonelec_deriv1_lag30     0
# IPDAILYage_75plus_elecnonelec_deriv2_lag30     0
# EDDAILYINT_atten_ip_deriv1_lag7                0
# EDDAILYINT_atten_ip_deriv2_lag7                0
# EDDAILYINT_atten_ip_deriv1_lag14               0
# EDDAILYINT_atten_ip_deriv2_lag14               0
# EDDAILYINT_atten_ip_deriv1_lag30               0
# EDDAILYINT_atten_ip_deriv2_lag30               0
# EDDAILYINT_adm_ipage_deriv1_lag7               0
# EDDAILYINT_adm_ipage_deriv2_lag7               0
# EDDAILYINT_adm_ipage_deriv1_lag14              0
# EDDAILYINT_adm_ipage_deriv2_lag14              0
# EDDAILYINT_adm_ipage_deriv1_lag30              0
# EDDAILYINT_adm_ipage_deriv2_lag30              0
# Length: 101, dtype: int64

# %%
features_final.dropna(inplace=True)

# %% [markdown]
# # Processing
#
# #### split test and train sets

# %%
from src.data.preprocess import make_timeseries_test_train_splits

# %%
X_train, X_test, y_train, y_test = make_timeseries_test_train_splits(features_final, 'flag_target', 365)
# Out:
# DATA POINTS:
# orig size 2437
# training:  2072
# testing:  365

# %%
from src.data.preprocess import get_variable_types_lists, check_for_catagorical_type_difference_between_train_test, change_feature_types_to_numeric
    

# num_features, cat_features, bin_features = get_variable_types_lists(X_train)

# %%
X_train.columns
# Out:
# Index(['TARGET_prevday', 'EDDAILYattendances', 'EDDAILYadmissions',
#        'EDDAILYage_mean', 'EDDAILYage_75plus', 'IPDAILYpatients_total',
#        'IPDAILYpatients_nonelec', 'IPDAILYpatients_elec',
#        'IPDAILYpatients_daycase', 'IPDAILYage_mean_elecnonelec',
#        'IPDAILYage_75plus_elecnonelec', 'year', 'month', 'dayofweek',
#        'flag_target_prevday', 'time', 'IPDAILYpatients_nonelec_elec',
#        'EDDAILYINT_atten_ip', 'EDDAILYINT_adm_ipage', 'TARGET_prevday_lag6',
#        'TARGET_prevday_lag13', 'TARGET_prevday_lag27',
#        'TARGET_prevday_deriv1_lag7', 'TARGET_prevday_deriv2_lag7',
#        'TARGET_prevday_deriv1_lag14', 'TARGET_prevday_deriv2_lag14',
#        'TARGET_prevday_deriv1_lag30', 'TARGET_prevday_deriv2_lag30',
#        'EDDAILYattendances_deriv1_lag7', 'EDDAILYattendances_deriv2_lag7',
#        'EDDAILYattendances_deriv1_lag14', 'EDDAILYattendances_deriv2_lag14',
#        'EDDAILYattendances_deriv1_lag30', 'EDDAILYattendances_deriv2_lag30',
#        'EDDAILYadmissions_deriv1_lag7', 'EDDAILYadmissions_deriv2_lag7',
#        'EDDAILYadmissions_deriv1_lag14', 'EDDAILYadmissions_deriv2_lag14',
#        'EDDAILYadmissions_deriv1_lag30', 'EDDAILYadmissions_deriv2_lag30',
#        'EDDAILYage_mean_deriv1_lag7', 'EDDAILYage_mean_deriv2_lag7',
#        'EDDAILYage_mean_deriv1_lag14', 'EDDAILYage_mean_deriv2_lag14',
#        'EDDAILYage_mean_deriv1_lag30', 'EDDAILYage_mean_deriv2_lag30',
#        'EDDAILYage_75plus_deriv1_lag7', 'EDDAILYage_75plus_deriv2_lag7',
#        'EDDAILYage_75plus_deriv1_lag14', 'EDDAILYage_75plus_deriv2_lag14',
#        'EDDAILYage_75plus_deriv1_lag30', 'EDDAILYage_75plus_deriv2_lag30',
#        'IPDAILYpatients_total_deriv1_lag7',
#        'IPDAILYpatients_total_deriv2_lag7',
#        'IPDAILYpatients_total_deriv1_lag14',
#        'IPDAILYpatients_total_deriv2_lag14',
#        'IPDAILYpatients_total_deriv1_lag30',
#        'IPDAILYpatients_total_deriv2_lag30',
#        'IPDAILYpatients_nonelec_deriv1_lag7',
#        'IPDAILYpatients_nonelec_deriv2_lag7',
#        'IPDAILYpatients_nonelec_deriv1_lag14',
#        'IPDAILYpatients_nonelec_deriv2_lag14',
#        'IPDAILYpatients_nonelec_deriv1_lag30',
#        'IPDAILYpatients_nonelec_deriv2_lag30',
#        'IPDAILYpatients_elec_deriv1_lag7', 'IPDAILYpatients_elec_deriv2_lag7',
#        'IPDAILYpatients_elec_deriv1_lag14',
#        'IPDAILYpatients_elec_deriv2_lag14',
#        'IPDAILYpatients_elec_deriv1_lag30',
#        'IPDAILYpatients_elec_deriv2_lag30',
#        'IPDAILYpatients_daycase_deriv1_lag7',
#        'IPDAILYpatients_daycase_deriv2_lag7',
#        'IPDAILYpatients_daycase_deriv1_lag14',
#        'IPDAILYpatients_daycase_deriv2_lag14',
#        'IPDAILYpatients_daycase_deriv1_lag30',
#        'IPDAILYpatients_daycase_deriv2_lag30',
#        'IPDAILYage_mean_elecnonelec_deriv1_lag7',
#        'IPDAILYage_mean_elecnonelec_deriv2_lag7',
#        'IPDAILYage_mean_elecnonelec_deriv1_lag14',
#        'IPDAILYage_mean_elecnonelec_deriv2_lag14',
#        'IPDAILYage_mean_elecnonelec_deriv1_lag30',
#        'IPDAILYage_mean_elecnonelec_deriv2_lag30',
#        'IPDAILYage_75plus_elecnonelec_deriv1_lag7',
#        'IPDAILYage_75plus_elecnonelec_deriv2_lag7',
#        'IPDAILYage_75plus_elecnonelec_deriv1_lag14',
#        'IPDAILYage_75plus_elecnonelec_deriv2_lag14',
#        'IPDAILYage_75plus_elecnonelec_deriv1_lag30',
#        'IPDAILYage_75plus_elecnonelec_deriv2_lag30',
#        'EDDAILYINT_atten_ip_deriv1_lag7', 'EDDAILYINT_atten_ip_deriv2_lag7',
#        'EDDAILYINT_atten_ip_deriv1_lag14', 'EDDAILYINT_atten_ip_deriv2_lag14',
#        'EDDAILYINT_atten_ip_deriv1_lag30', 'EDDAILYINT_atten_ip_deriv2_lag30',
#        'EDDAILYINT_adm_ipage_deriv1_lag7', 'EDDAILYINT_adm_ipage_deriv2_lag7',
#        'EDDAILYINT_adm_ipage_deriv1_lag14',
#        'EDDAILYINT_adm_ipage_deriv2_lag14',
#        'EDDAILYINT_adm_ipage_deriv1_lag30',
#        'EDDAILYINT_adm_ipage_deriv2_lag30'],
#       dtype='object')

# %%
cat_features = ['month','dayofweek']
num_features = list(set(X_train.columns) - set(cat_features))
bin_features = []

# %% [markdown]
# #### find problem columns that will crash preprocessing pipleine when converting test data

# %%
problem_col_list = check_for_catagorical_type_difference_between_train_test(X_train, X_test, cat_features)

# %%
problem_col_list

# %% [markdown]
# Treat problem features as numerical so that process can continue.

# %% [markdown]
# - use sklearn pipelines to clean

# %%
# version 19.2
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder 

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

from src.data.preprocess import DataFrameSelector, MakeBooleanAnInteger

# %% [markdown]
# for col_name in cat_features:
#     values_list = X_train[col_name].unique()
#     for value in values_list:
#         print(col_name + '_' + str(value))

# %%
#### failed to get this to work as kept doubling size of output array. Didnt matter if get_col_list_for_after_pipeline fundtion was inside or outside of DataFrameReform class.


from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameReform(BaseEstimator,TransformerMixin):
    " Takes numpy array and forms into dataframe with column names."
    def __init__(self, new_features_list):
        self.new_features_list = new_features_list
    def fit(self, X, y=None):
        return self
    def transform(self,X):        
        return(pd.DataFrame(X, columns = self.new_features_list))

# %%
num_pipeline = Pipeline([
    ('selector',DataFrameSelector(num_features)),
    # lagger
    # derivative
    ('feature_filter',SelectKBest(f_classif,k='all')),
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

cat_pipeline = Pipeline([
    ('selector',DataFrameSelector(cat_features)),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('OneHot_encoder',OneHotEncoder(sparse=False))
])

bin_pipeline = Pipeline([
    ('selector',DataFrameSelector(bin_features)),
    ('boolean_conversion',MakeBooleanAnInteger()),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    #('encoding',LabelEncoder()),
])

# df_reform_pipeline = Pipeline([
#     ('reform_df', DataFrameReform(new_features_list))
# ])

#### create list of pipelines to include

pipes_list = [
    ('num_pipeline',num_pipeline),
  ('cat_pipeline',cat_pipeline),
#   ('bin_pipeline',bin_pipeline),
#     ('df_reform_pipeline', df_reform_pipeline)
]

full_pipeline = FeatureUnion(transformer_list=pipes_list
)


X_trainT = full_pipeline.fit_transform(X_train,y_train)
X_testT = full_pipeline.transform(X_test)

# %%
X_train.shape
# Out:
# (2072, 100)

# %%
X_trainT.shape
# Out:
# (2072, 117)

# %%
def get_col_list_for_after_pipeline(X, num_features, cat_features, bin_features):
    cat_features_new = []
    #### get new names for cat_features - must do here, otherwise when call fit transform the cat_features_new is appedned too twice.
#     print('TRANSFORM METHOD')
    for col_name in cat_features:
#         print('CAT FEATURES LOOP', col_name)
        values_list = X[col_name].unique()
        for value in values_list:
            cat_features_new.append(col_name + '_' + str(value))
#         print(cat_features_new)
    
    columns_list = num_features + cat_features_new + bin_features
#     print(len(columns_list))
    return(columns_list)

new_features_list = get_col_list_for_after_pipeline(X_train, num_features, cat_features, bin_features)

# %%
def reform_df(X, new_features_list):
    return(pd.DataFrame(X, columns= new_features_list))

X_trainT = reform_df(X_trainT, new_features_list)
X_testT = reform_df(X_testT, new_features_list)

# %%
X_testT.shape
# Out:
# (365, 117)

# %%
X_trainT.shape
# Out:
# (2072, 117)

# %%
X_testT.shape
# Out:
# (365, 117)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import classification_report,precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_curve,roc_curve
from sklearn.model_selection import TimeSeriesSplit

from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV



def find_best_model(model, grid, Xdata, ydata, plot_label):
    """does gridsearch for model and plots result from """
    my_cv = TimeSeriesSplit(n_splits=5).split(Xdata) # 5 chosen as gives roughly 1 year groups for each fold
    grid_search = GridSearchCV(model,grid,scoring='f1',cv=my_cv,return_train_score=True)
    grid_search.fit(Xdata,ydata)
    model = grid_search.best_estimator_
    print('CV MODEL RESULTS')
    print(grid_search.best_params_)
    print(pd.DataFrame(grid_search.cv_results_).query('rank_test_score == 1')[['mean_test_score','mean_train_score']])
    
#     plot_model_perf(ydata,Xdata,model,plot_label)

    
    return(grid_search)

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression(solver='liblinear',class_weight ='balanced')

# %%
grid = {'C':[0.01, 0.05, 0.1,0.2,0.3,0.5,0.7,1,3,10],
       'penalty':['l1','l2']}
# grid = {'C':[0.1]}

grid_search = find_best_model(lgr, grid, X_trainT, y_train, 'CV set')
# Out:
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# CV MODEL RESULTS
# {'C': 0.05, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.446081          0.527408

# %%
data = grid_search.best_estimator_.coef_[0,:]
cols = list(X_trainT.columns)
important_features = pd.DataFrame(data=data, index=cols, columns=['coef']).sort_values('coef',ascending=False)

# %%
important_features.head(50)
# Out:
#                                                 coef
# month_9                                     1.261283
# dayofweek_Wednesday                         1.197242
# dayofweek_Tuesday                           1.172102
# IPDAILYpatients_daycase                     0.896481
# dayofweek_Friday                            0.855413
# IPDAILYpatients_daycase_deriv2_lag30        0.807336
# TARGET_prevday                              0.750942
# dayofweek_Saturday                          0.737291
# month_1                                     0.682603
# EDDAILYadmissions_deriv1_lag14              0.675480
# IPDAILYpatients_nonelec_deriv1_lag30        0.651295
# IPDAILYpatients_nonelec_deriv2_lag30        0.542941
# EDDAILYadmissions_deriv2_lag14              0.463751
# IPDAILYpatients_nonelec_deriv2_lag14        0.462895
# dayofweek_Thursday                          0.455134
# month_12                                    0.442568
# IPDAILYage_mean_elecnonelec_deriv2_lag14    0.441634
# IPDAILYpatients_nonelec_deriv1_lag14        0.370341
# EDDAILYage_75plus_deriv2_lag30              0.368523
# month_3                                     0.327456
# EDDAILYage_75plus_deriv2_lag14              0.326497
# EDDAILYage_75plus_deriv1_lag14              0.320134
# IPDAILYage_75plus_elecnonelec_deriv2_lag14  0.281552
# IPDAILYage_mean_elecnonelec_deriv1_lag14    0.277660
# EDDAILYage_75plus_deriv1_lag30              0.277604
# month_6                                     0.267677
# IPDAILYpatients_elec_deriv2_lag14           0.251440
# month_4                                     0.228940
# IPDAILYpatients_elec_deriv2_lag30           0.205619
# IPDAILYpatients_daycase_deriv1_lag30        0.184141

# %% [markdown]
# ## Search for best features
# Loop over LGR model and remove lest useful features each

# %%
#### make copy o feature data
X_trainTD = X_trainT.copy()
no_features = X_trainTD.shape[1]

mean_test_score = []
mean_train_score = []
number_features = []

# for loop in np.arange(0,10):
while no_features > 30:
    number_features.append(no_features)
    grid = {
        'C':[0.05, 0.1,0.2,0.3,0.5,0.7,1],
       'penalty':['l2'] # 'l1',
    }
    
    #### train model
    grid_search = find_best_model(lgr, grid, X_trainTD, y_train, 'CV set')
    
    #### find feature importance
    data = grid_search.best_estimator_.coef_[0,:]
    cols = list(X_trainTD.columns)
    important_features = pd.DataFrame(data=data, index=cols, columns=['coef'])
    important_features['coef'] = important_features.coef.abs()
    important_features = important_features.sort_values('coef',ascending=False)
    
    #### save/print info
    no_features = X_trainTD.shape[1]
    print('No. features: ' , no_features)
    
    scores_df = (pd.DataFrame(grid_search.cv_results_).query('rank_test_score == 1')[['mean_test_score','mean_train_score']])
    
    mean_test_score.append(scores_df.mean_test_score.values[0])
    mean_train_score.append(scores_df.mean_train_score.values[0])
    
    #### find features to remove
    col_to_drop = list(important_features[(important_features["coef"] < 0.05)].index)
    if len(col_to_drop) == 0:
        col_to_drop = list(important_features[-1:].index)
    
    #### remove features
    X_trainTD = X_trainTD.drop(col_to_drop,axis=1)
    

    
data = {'mean_test_score':mean_test_score, 'mean_train_score':mean_train_score, 'number_features':number_features}
scores_history = pd.DataFrame(data).set_index('number_features')
# Out:
# CV MODEL RESULTS
# {'C': 0.05, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 0         0.446081          0.527408
# No. features:  117
# CV MODEL RESULTS
# {'C': 0.05, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 0         0.450767          0.524734
# No. features:  88
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.460394          0.549647
# No. features:  82
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.460857            0.5546
# No. features:  78
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.455369          0.552371
# No. features:  73
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.455299          0.547708
# No. features:  72
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.455939           0.54701
# No. features:  71
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.458949          0.546733
# No. features:  70
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.456387          0.553529
# No. features:  69
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.459765          0.550772
# No. features:  68
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.454761          0.551211
# No. features:  67
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.452876          0.551154
# No. features:  66
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.453344          0.552159
# No. features:  65
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5          0.45292          0.550648
# No. features:  64
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.453578          0.552854
# No. features:  63
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.455729          0.546808
# No. features:  62
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.462996          0.545843
# No. features:  61
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.464021          0.541931
# No. features:  60
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.464486          0.544333
# No. features:  59
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 6         0.464013          0.549111
# No. features:  58
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 6         0.456697          0.548423
# No. features:  57
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 6         0.457703          0.549263
# No. features:  56
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 6         0.458142          0.546171
# No. features:  55
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.458691           0.53923
# No. features:  54
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.458356          0.537428
# No. features:  53
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.456323          0.539261
# No. features:  52
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.457834          0.541679
# No. features:  51
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.459041          0.536848
# No. features:  50
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 1         0.453954          0.521037
# No. features:  49
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.456849          0.540833
# No. features:  48
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 5         0.461152          0.537947
# No. features:  47
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4         0.460448          0.537442
# No. features:  46
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.460108          0.534284
# No. features:  45
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.462057          0.537539
# No. features:  44
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 4          0.45998           0.53399
# No. features:  43
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.459316          0.529306
# No. features:  42
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.461824          0.533971
# No. features:  41
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.461803          0.532154
# No. features:  40
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.461811          0.531909
# No. features:  39
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.462819          0.532632
# No. features:  38
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.459096          0.532077
# No. features:  37
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2          0.45736          0.529127
# No. features:  36
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.464797          0.527158
# No. features:  35
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.462761           0.52579
# No. features:  34
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3         0.464585          0.528871
# No. features:  33
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 3          0.46703          0.528725
# No. features:  32
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 2         0.462849          0.526421
# No. features:  31
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 6         0.461593          0.530091
# No. features:  30

# %%
# %matplotlib inline
scores_history.plot()

# %%
# %matplotlib inline
scores_history.plot()

# %%
important_features
# Out:
#                                                 coef
# dayofweek_Friday                            1.390561
# month_9                                     1.076539
# dayofweek_Saturday                          1.055840
# dayofweek_Tuesday                           0.997513
# TARGET_prevday                              0.886166
# EDDAILYattendances_deriv2_lag7              0.832162
# dayofweek_Thursday                          0.786889
# IPDAILYage_mean_elecnonelec_deriv2_lag14    0.728603
# EDDAILYINT_atten_ip_deriv1_lag3             0.725298
# IPDAILYpatients_daycase_deriv2_lag30        0.715287
# EDDAILYage_75plus_deriv1_lag5               0.677043
# EDDAILYINT_atten_ip_deriv1_lag7             0.649819
# IPDAILYpatients_nonelec_deriv2_lag14        0.646729
# IPDAILYpatients_nonelec_deriv1_lag14        0.546838
# IPDAILYage_mean_elecnonelec_deriv1_lag14    0.521312
# EDDAILYattendances_deriv2_lag3              0.509866
# IPDAILYpatients_nonelec_deriv2_lag30        0.508996
# EDDAILYage_75plus_deriv1_lag2               0.500053
# EDDAILYINT_atten_ip_deriv2_lag7             0.498219
# IPDAILYpatients_total_deriv2_lag2           0.497312
# IPDAILYage_75plus_elecnonelec_deriv1_lag7   0.496757
# month_12                                    0.490599
# EDDAILYage_mean_deriv2_lag3                 0.487685
# IPDAILYpatients_total_deriv1_lag5           0.484155
# month_3                                     0.482443
# month_2                                     0.474461
# IPDAILYpatients_elec_deriv2_lag3            0.473639
# IPDAILYpatients_nonelec_deriv1_lag30        0.468087
# EDDAILYage_mean_deriv1_lag2                 0.462368
# IPDAILYage_75plus_elecnonelec_deriv2_lag14  0.439705
# ...                                              ...
# IPDAILYpatients_daycase_deriv1_lag5         0.415904
# EDDAILYadmissions_deriv2_lag14              0.408940
# EDDAILYage_75plus_deriv2_lag2               0.385697
# TARGET_prevday_deriv1_lag5                  0.362212
# EDDAILYadmissions_deriv1_lag14              0.358181
# EDDAILYage_75plus_deriv1_lag14              0.357899
# EDDAILYadmissions_deriv2_lag1               0.357114
# EDDAILYage_75plus_deriv2_lag5               0.353995
# EDDAILYage_mean_deriv2_lag2                 0.351824
# EDDAILYINT_adm_ipage_deriv1_lag14           0.344909
# EDDAILYattendances_deriv1_lag30             0.342127
# EDDAILYage_75plus_deriv2_lag14              0.325918
# IPDAILYage_75plus_elecnonelec_deriv1_lag1   0.317960
# IPDAILYpatients_elec_deriv1_lag5            0.314636
# EDDAILYage_75plus                           0.314076
# EDDAILYage_75plus_deriv1_lag30              0.313755
# EDDAILYage_75plus_deriv2_lag30              0.303874
# EDDAILYadmissions_deriv2_lag5               0.297104
# IPDAILYpatients_elec_deriv2_lag14           0.291083
# EDDAILYage_mean_deriv1_lag3                 0.285723
# TARGET_prevday_deriv2_lag5                  0.276858
# IPDAILYage_mean_elecnonelec                 0.274812
# TARGET_prevday_deriv2_lag14                 0.265286
# month_6                                     0.261952
# TARGET_prevday_deriv1_lag1                  0.254347
# month_7                                     0.252348
# IPDAILYage_mean_elecnonelec_deriv1_lag7     0.251276
# IPDAILYpatients_daycase_deriv1_lag14        0.248479
# IPDAILYpatients_elec_deriv2_lag30           0.232274
# month_5                                     0.213188
#
# [62 rows x 1 columns]

# %%
break
# Out:
#   File "<ipython-input-39-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %% [markdown]
# NOTE: consider creating log for preprocessing information in order for repeatability in future.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', lgr, grid_search, 'Uses all features + derivatives from previous day. l1 pen iterated over all variables to reduce number of vars. in D2_daily_data_to_model_FULLPIPELINE_find best features.ipynb.')
# Out:
# Model logged.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', lgr, grid_search, 'Uses all features + derivatives from previous day. l2 pen iterated over all variables (rm coef < 0.05 or 1) to reduce number of vars. in D2_daily_data_to_model_FULLPIPELINE_find best features.ipynb.')
# Out:
# Model logged.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', rf, grid_search, 'Model uses all derivative features from previous day. in D2_daily_data_to_model_FULLPIPELINE.ipynb.')
# Out:
# Model logged.

# %%
models = pd.read_pickle('./../../data/output/model_log.pkl')
# models.drop(3,inplace=True)
models
# Out:
#   dataV                                              model  \
# 0    v1  LogisticRegression(C=0.3, class_weight='balanc...
# 1    v1  (DecisionTreeClassifier(class_weight=None, cri...
# 2    v1  XGBClassifier(base_score=0.5, booster='gbtree'...
# 3    D2  RandomForestClassifier(bootstrap=True, class_w...
# 4    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 5    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 6    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 7    D2  LogisticRegression(C=1.0, class_weight='balanc...
#
#                                           gridsearch mean_train mean_valid  \
# 0     mean_fit_time  std_fit_time  mean_score_tim...    [0.629]     [0.52]
# 1      mean_fit_time  std_fit_time  mean_score_ti...    [0.685]    [0.419]
# 2     mean_fit_time  std_fit_time  mean_score_tim...    [0.829]    [0.439]
# 3     mean_fit_time  std_fit_time  mean_score_tim...     [0.64]    [0.454]
# 4      mean_fit_time  std_fit_time  mean_score_ti...    [0.489]    [0.445]
# 5      mean_fit_time  std_fit_time  mean_score_ti...    [0.515]    [0.448]
# 6     mean_fit_time  std_fit_time  mean_score_tim...    [0.552]    [0.486]
# 7     mean_fit_time  std_fit_time  mean_score_tim...    [0.577]    [0.494]
#
#                                                notes
# 0  Initial model which was built on first edition...
# 1                 Random Forest 1st attempt with v1.
# 2  V1 attempt with XGBOOST. KFOLD selection of fe...
# 3  Model uses all derivative features from previo...
# 4  Model uses all derivative features from previo...
# 5  only target features from previous day + der+l...
# 6  Uses all features + derivatives from previous ...
# 7  Uses all features + derivatives from previous ...

# %%
models.to_pickle('./../../data/output/model_log.pkl')
