# %% [markdown]
# # Notebook used to help create:
#
# - importing data src
# - precprocessing data src

# %%
# %pwd
# Out:
# 'C:\\Users\\bjk1y13\\OneDrive - University of Southampton\\MH028_UHS_Weather\\4_Analysis\\EDclassification\\notebooks\\model'

# %%
import pandas as pd
import numpy as np
from src.data.io import import_pickled_feature_dfs, import_merge_prevday_target_column, import_merge_pickled_target_class

# %% [markdown]
# # Import data

# %%
features = import_pickled_feature_dfs('../../data/interim/D2_timeseries/', ['EDdaily.pkl', 'IPdaily.pkl','EDmorn.pkl', 'IPmorn.pkl' ,'callender.pkl'])

# %%
features.shape
# Out:
# (2465, 22)

# %%
features.tail()
# Out:
#            EDDAILYattendances EDDAILYadmissions EDDAILYage_mean  \
#
# 2018-09-26                446               182         42.9126
# 2018-09-27                487               188         44.7064
# 2018-09-28                482               168         44.1992
# 2018-09-29                463               191         46.4989
# 2018-09-30                367               157         40.3597
#
#            EDDAILYage_75plus IPDAILYpatients_total IPDAILYpatients_nonelec  \
#
# 2018-09-26                62                     2                       1
# 2018-09-27                82                     2                       1
# 2018-09-28                74                     2                       1
# 2018-09-29                84                     1                       0
# 2018-09-30                47                     1                       0
#
#            IPDAILYpatients_elec IPDAILYpatients_daycase  \
#
# 2018-09-26                    1                       0
# 2018-09-27                    1                       0
# 2018-09-28                    1                       0
# 2018-09-29                    1                       0
# 2018-09-30                    1                       0
#
#            IPDAILYage_mean_elecnonelec IPDAILYage_75plus_elecnonelec  ...  \
#                                                                       ...
# 2018-09-26                        35.5                             0  ...
# 2018-09-27                        35.5                             0  ...
# 2018-09-28                        35.5                             0  ...
# 2018-09-29                           0                             0  ...
# 2018-09-30                           0                             0  ...
#
#            EDMORNage_75plus IPMORNIPMORNpatients_total  \
#
# 2018-09-26               10                          2
# 2018-09-27               17                          2
# 2018-09-28               12                          1
# 2018-09-29                7                          1
# 2018-09-30                7                          1
#
#            IPMORNIPMORNpatients_nonelec IPMORNIPMORNpatients_elec  \
#
# 2018-09-26                            1                         1
# 2018-09-27                            1                         1
# 2018-09-28                            0                         1
# 2018-09-29                            0                         1
# 2018-09-30                            0                         1
#
#            IPMORNIPMORNpatients_daycase IPMORNIPMORNage_mean_elecnonelec  \
#
# 2018-09-26                            0                             35.5
# 2018-09-27                            0                             35.5
# 2018-09-28                            0                                0
# 2018-09-29                            0                                0
# 2018-09-30                            0                                0
#
#            IPMORNIPMORNage_75plus_elecnonelec  year month  dayofweek
#
# 2018-09-26                                  0  2018     9  Wednesday
# 2018-09-27                                  0  2018     9   Thursday
# 2018-09-28                                  0  2018     9     Friday
# 2018-09-29                                  0  2018     9   Saturday
# 2018-09-30                                  0  2018     9     Sunday
#
# [5 rows x 22 columns]

# %%
target = pd.read_pickle('../../data/interim/EDooc_class.pkl')

# %%
features = target.merge(features, right_index=True, left_index=True)

# %% [markdown]
# Remember target does not need to be offset because features were calculated for the previous days records

# %%
features_final = features.copy()
# features_final['flag_target'] = features_final['flag_target'].shift(-1)
##### we do shift the EDocc col as this is for the current date in index.
features_final['EDocc'] = features_final['EDocc'].shift(1)

# %%
features_final.rename(columns={'EDocc':'TARGET_prevday'},inplace=True)

# %%
features_final['flag_target_prevday'] = features_final['flag_target'].shift(1)

# %%
features_final.flag_target.value_counts()
# Out:
# 0    2094
# 1     371
# Name: flag_target, dtype: int64

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-01             NaN            1                NaN               NaN
# 2012-01-02       55.750000            0                377               151
# 2012-01-03       38.541667            0                350               139
# 2012-01-04       40.208333            0                356               125
# 2012-01-05       32.375000            0                284                92
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-01             NaN               NaN                   NaN
# 2012-01-02         40.0186                59                  1185
# 2012-01-03         42.2114                44                  1228
# 2012-01-04         45.1011                58                  1564
# 2012-01-05         42.5035                49                  1535
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-01                     NaN                  NaN
# 2012-01-02                    1001                  141
# 2012-01-03                    1037                  141
# 2012-01-04                    1074                  208
# 2012-01-05                    1066                  241
#
#            IPDAILYpatients_daycase  ... IPMORNIPMORNpatients_total  \
# dt_date                             ...
# 2012-01-01                     NaN  ...                       1025
# 2012-01-02                      43  ...                       1059
# 2012-01-03                      50  ...                       1098
# 2012-01-04                     282  ...                       1177
# 2012-01-05                     228  ...                       1178
#
#            IPMORNIPMORNpatients_nonelec IPMORNIPMORNpatients_elec  \
# dt_date
# 2012-01-01                          879                       137
# 2012-01-02                          924                       123
# 2012-01-03                          954                       127
# 2012-01-04                          975                       191
# 2012-01-05                          960                       205
#
#            IPMORNIPMORNpatients_daycase IPMORNIPMORNage_mean_elecnonelec  \
# dt_date
# 2012-01-01                            9                          59.1883
# 2012-01-02                           12                          59.5061
# 2012-01-03                           17                          59.1002
# 2012-01-04                           11                          58.2591
# 2012-01-05                           13                          57.6664
#
#            IPMORNIPMORNage_75plus_elecnonelec  year month  dayofweek  \
# dt_date
# 2012-01-01                                411  2012     1     Sunday
# 2012-01-02                                427  2012     1     Monday
# 2012-01-03                                435  2012     1    Tuesday
# 2012-01-04                                455  2012     1  Wednesday
# 2012-01-05                                455  2012     1   Thursday
#
#            flag_target_prevday
# dt_date
# 2012-01-01                 NaN
# 2012-01-02                 1.0
# 2012-01-03                 0.0
# 2012-01-04                 0.0
# 2012-01-05                 0.0
#
# [5 rows x 25 columns]

# %%
#### add time feature
features_final['time'] = np.arange(0,len(features_final))

# %%
features_final.columns
# Out:
# Index(['TARGET_prevday', 'flag_target', 'EDDAILYattendances',
#        'EDDAILYadmissions', 'EDDAILYage_mean', 'EDDAILYage_75plus',
#        'IPDAILYpatients_total', 'IPDAILYpatients_nonelec',
#        'IPDAILYpatients_elec', 'IPDAILYpatients_daycase',
#        'IPDAILYage_mean_elecnonelec', 'IPDAILYage_75plus_elecnonelec',
#        'EDMORNoccupancy', 'EDMORNage_mean', 'EDMORNage_75plus',
#        'IPMORNIPMORNpatients_total', 'IPMORNIPMORNpatients_nonelec',
#        'IPMORNIPMORNpatients_elec', 'IPMORNIPMORNpatients_daycase',
#        'IPMORNIPMORNage_mean_elecnonelec',
#        'IPMORNIPMORNage_75plus_elecnonelec', 'year', 'month', 'dayofweek',
#        'flag_target_prevday', 'time'],
#       dtype='object')

# %% [markdown]
# IP occ data after 2018-5-31 is not valid. NOTE: must check if that is same in RAW.

# %% [markdown]
# ## Add new lagged and derivative features

# %%
from src.features.feature_gen import create_lagged_vars_list

features_final = create_lagged_vars_list(features_final, 'TARGET_prevday', [6])

# %%
from src.features.feature_gen import perform_deriv_cals_multiple_columns

# %% [markdown]
# lags_required = {
#                 'TARGET_prevday':[1,3,5,7,14,30],
#                  'EDDAILYattendances':[1,2,3,5,7,14,30],
#                 'EDDAILYadmissions':[1,2,3,5,7,14,30],
#                  'EDDAILYage_mean':[1,2,3,5,7,14,30],
#                 'EDDAILYage_75plus':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_total':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_nonelec':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_elec':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_daycase':[1,2,3,5,7,14,30],
#                  'IPDAILYage_mean_elecnonelec':[1,2,3,5,7,14,30],
#                  'IPDAILYage_75plus_elecnonelec':[1,2,3,5,7,14,30],
#
#
#                 }
# features_final = perform_deriv_cals_multiple_columns(features_final, lags_required, 2)

# %%
lags_required = {
                'TARGET_prevday':[7,14],
                 'EDDAILYattendances':[7,14],
                'EDDAILYadmissions':[7,14],
#                  'EDDAILYage_mean':[7,14], 
                'EDDAILYage_75plus':[7,14],
#                  'IPDAILYpatients_total':[7,14],
                 'IPDAILYpatients_nonelec':[7,14],
                 'IPDAILYpatients_elec':[7,14],
                 'IPDAILYpatients_daycase':[7,14],
#                  'IPDAILYage_mean_elecnonelec':[7,14],
#                  'IPDAILYage_75plus_elecnonelec':[7,14],
                 
                
                }
features_final = perform_deriv_cals_multiple_columns(features_final, lags_required, 2)

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-01             NaN            1                NaN               NaN
# 2012-01-02       55.750000            0                377               151
# 2012-01-03       38.541667            0                350               139
# 2012-01-04       40.208333            0                356               125
# 2012-01-05       32.375000            0                284                92
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-01             NaN               NaN                   NaN
# 2012-01-02         40.0186                59                  1185
# 2012-01-03         42.2114                44                  1228
# 2012-01-04         45.1011                58                  1564
# 2012-01-05         42.5035                49                  1535
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-01                     NaN                  NaN
# 2012-01-02                    1001                  141
# 2012-01-03                    1037                  141
# 2012-01-04                    1074                  208
# 2012-01-05                    1066                  241
#
#            IPDAILYpatients_daycase  ... IPDAILYpatients_nonelec_deriv1_lag14  \
# dt_date                             ...
# 2012-01-01                     NaN  ...                                -64.0
# 2012-01-02                      43  ...                                -64.0
# 2012-01-03                      50  ...                                -64.0
# 2012-01-04                     282  ...                                -64.0
# 2012-01-05                     228  ...                                -64.0
#
#            IPDAILYpatients_nonelec_deriv2_lag14  \
# dt_date
# 2012-01-01                                 50.0
# 2012-01-02                                 50.0
# 2012-01-03                                 50.0
# 2012-01-04                                 50.0
# 2012-01-05                                 50.0
#
#            IPDAILYpatients_elec_deriv1_lag7 IPDAILYpatients_elec_deriv2_lag7  \
# dt_date
# 2012-01-01                             90.0                            -69.0
# 2012-01-02                             90.0                            -69.0
# 2012-01-03                             90.0                            -69.0
# 2012-01-04                             90.0                            -69.0
# 2012-01-05                             90.0                            -69.0
#
#            IPDAILYpatients_elec_deriv1_lag14  \
# dt_date
# 2012-01-01                             111.0
# 2012-01-02                             111.0
# 2012-01-03                             111.0
# 2012-01-04                             111.0
# 2012-01-05                             111.0
#
#            IPDAILYpatients_elec_deriv2_lag14  \
# dt_date
# 2012-01-01                            -113.0
# 2012-01-02                            -113.0
# 2012-01-03                            -113.0
# 2012-01-04                            -113.0
# 2012-01-05                            -113.0
#
#            IPDAILYpatients_daycase_deriv1_lag7  \
# dt_date
# 2012-01-01                                26.0
# 2012-01-02                                26.0
# 2012-01-03                                26.0
# 2012-01-04                                26.0
# 2012-01-05                                26.0
#
#            IPDAILYpatients_daycase_deriv2_lag7  \
# dt_date
# 2012-01-01                               -47.0
# 2012-01-02                               -47.0
# 2012-01-03                               -47.0
# 2012-01-04                               -47.0
# 2012-01-05                               -47.0
#
#            IPDAILYpatients_daycase_deriv1_lag14  \
# dt_date
# 2012-01-01                                  5.0
# 2012-01-02                                  5.0
# 2012-01-03                                  5.0
# 2012-01-04                                  5.0
# 2012-01-05                                  5.0
#
#            IPDAILYpatients_daycase_deriv2_lag14
# dt_date
# 2012-01-01                                 12.0
# 2012-01-02                                 12.0
# 2012-01-03                                 12.0
# 2012-01-04                                 12.0
# 2012-01-05                                 12.0
#
# [5 rows x 55 columns]

# %%
features_final.tail()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2018-09-26       53.541667            0                446               182
# 2018-09-27       59.791667            1                487               188
# 2018-09-28       63.250000            0                482               168
# 2018-09-29       56.541667            0                463               191
# 2018-09-30       44.125000            0                367               157
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2018-09-26         42.9126                62                     2
# 2018-09-27         44.7064                82                     2
# 2018-09-28         44.1992                74                     2
# 2018-09-29         46.4989                84                     1
# 2018-09-30         40.3597                47                     1
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2018-09-26                       1                    1
# 2018-09-27                       1                    1
# 2018-09-28                       1                    1
# 2018-09-29                       0                    1
# 2018-09-30                       0                    1
#
#            IPDAILYpatients_daycase  ... IPDAILYpatients_nonelec_deriv1_lag14  \
# dt_date                             ...
# 2018-09-26                       0  ...                                -10.0
# 2018-09-27                       0  ...                                 -8.0
# 2018-09-28                       0  ...                                 -7.0
# 2018-09-29                       0  ...                                 -7.0
# 2018-09-30                       0  ...                                 -6.0
#
#            IPDAILYpatients_nonelec_deriv2_lag14  \
# dt_date
# 2018-09-26                                 -7.0
# 2018-09-27                                 -4.0
# 2018-09-28                                 -2.0
# 2018-09-29                                 -1.0
# 2018-09-30                                  1.0
#
#            IPDAILYpatients_elec_deriv1_lag7 IPDAILYpatients_elec_deriv2_lag7  \
# dt_date
# 2018-09-26                              0.0                              1.0
# 2018-09-27                              0.0                              1.0
# 2018-09-28                              0.0                              1.0
# 2018-09-29                              0.0                              0.0
# 2018-09-30                              0.0                              0.0
#
#            IPDAILYpatients_elec_deriv1_lag14  \
# dt_date
# 2018-09-26                              -1.0
# 2018-09-27                              -1.0
# 2018-09-28                              -1.0
# 2018-09-29                               0.0
# 2018-09-30                               0.0
#
#            IPDAILYpatients_elec_deriv2_lag14  \
# dt_date
# 2018-09-26                               0.0
# 2018-09-27                               0.0
# 2018-09-28                               0.0
# 2018-09-29                               2.0
# 2018-09-30                               2.0
#
#            IPDAILYpatients_daycase_deriv1_lag7  \
# dt_date
# 2018-09-26                                 0.0
# 2018-09-27                                 0.0
# 2018-09-28                                 0.0
# 2018-09-29                                 0.0
# 2018-09-30                                 0.0
#
#            IPDAILYpatients_daycase_deriv2_lag7  \
# dt_date
# 2018-09-26                                 0.0
# 2018-09-27                                 0.0
# 2018-09-28                                 0.0
# 2018-09-29                                 0.0
# 2018-09-30                                 0.0
#
#            IPDAILYpatients_daycase_deriv1_lag14  \
# dt_date
# 2018-09-26                                  0.0
# 2018-09-27                                  0.0
# 2018-09-28                                  0.0
# 2018-09-29                                  0.0
# 2018-09-30                                  0.0
#
#            IPDAILYpatients_daycase_deriv2_lag14
# dt_date
# 2018-09-26                                  0.0
# 2018-09-27                                  0.0
# 2018-09-28                                  0.0
# 2018-09-29                                  0.0
# 2018-09-30                                  0.0
#
# [5 rows x 55 columns]

# %% [markdown]
# ## check and remove nans

# %%
features_final.isnull().sum()
# Out:
# TARGET_prevday                          1
# flag_target                             0
# EDDAILYattendances                      1
# EDDAILYadmissions                       1
# EDDAILYage_mean                         1
# EDDAILYage_75plus                       1
# IPDAILYpatients_total                   1
# IPDAILYpatients_nonelec                 1
# IPDAILYpatients_elec                    1
# IPDAILYpatients_daycase                 1
# IPDAILYage_mean_elecnonelec             1
# IPDAILYage_75plus_elecnonelec           1
# EDMORNoccupancy                         0
# EDMORNage_mean                          0
# EDMORNage_75plus                        0
# IPMORNIPMORNpatients_total              0
# IPMORNIPMORNpatients_nonelec            0
# IPMORNIPMORNpatients_elec               0
# IPMORNIPMORNpatients_daycase            0
# IPMORNIPMORNage_mean_elecnonelec        0
# IPMORNIPMORNage_75plus_elecnonelec      0
# year                                    0
# month                                   0
# dayofweek                               0
# flag_target_prevday                     1
# time                                    0
# TARGET_prevday_lag6                     7
# TARGET_prevday_deriv1_lag7              0
# TARGET_prevday_deriv2_lag7              0
# TARGET_prevday_deriv1_lag14             0
# TARGET_prevday_deriv2_lag14             0
# EDDAILYattendances_deriv1_lag7          0
# EDDAILYattendances_deriv2_lag7          0
# EDDAILYattendances_deriv1_lag14         0
# EDDAILYattendances_deriv2_lag14         0
# EDDAILYadmissions_deriv1_lag7           0
# EDDAILYadmissions_deriv2_lag7           0
# EDDAILYadmissions_deriv1_lag14          0
# EDDAILYadmissions_deriv2_lag14          0
# EDDAILYage_75plus_deriv1_lag7           0
# EDDAILYage_75plus_deriv2_lag7           0
# EDDAILYage_75plus_deriv1_lag14          0
# EDDAILYage_75plus_deriv2_lag14          0
# IPDAILYpatients_nonelec_deriv1_lag7     0
# IPDAILYpatients_nonelec_deriv2_lag7     0
# IPDAILYpatients_nonelec_deriv1_lag14    0
# IPDAILYpatients_nonelec_deriv2_lag14    0
# IPDAILYpatients_elec_deriv1_lag7        0
# IPDAILYpatients_elec_deriv2_lag7        0
# IPDAILYpatients_elec_deriv1_lag14       0
# IPDAILYpatients_elec_deriv2_lag14       0
# IPDAILYpatients_daycase_deriv1_lag7     0
# IPDAILYpatients_daycase_deriv2_lag7     0
# IPDAILYpatients_daycase_deriv1_lag14    0
# IPDAILYpatients_daycase_deriv2_lag14    0
# dtype: int64

# %%
features_final.dropna(inplace=True)

# %% [markdown]
# # Processing
#
# #### split test and train sets

# %%
from src.data.preprocess import make_timeseries_test_train_splits

# %%
X_train, X_test, y_train, y_test = make_timeseries_test_train_splits(features_final, 'flag_target', 365)
# Out:
# DATA POINTS:
# orig size 2458
# training:  2093
# testing:  365

# %%
from src.data.preprocess import get_variable_types_lists, check_for_catagorical_type_difference_between_train_test, change_feature_types_to_numeric
    

# num_features, cat_features, bin_features = get_variable_types_lists(X_train)

# %%
X_train.columns
# Out:
# Index(['TARGET_prevday', 'EDDAILYattendances', 'EDDAILYadmissions',
#        'EDDAILYage_mean', 'EDDAILYage_75plus', 'IPDAILYpatients_total',
#        'IPDAILYpatients_nonelec', 'IPDAILYpatients_elec',
#        'IPDAILYpatients_daycase', 'IPDAILYage_mean_elecnonelec',
#        'IPDAILYage_75plus_elecnonelec', 'EDMORNoccupancy', 'EDMORNage_mean',
#        'EDMORNage_75plus', 'IPMORNIPMORNpatients_total',
#        'IPMORNIPMORNpatients_nonelec', 'IPMORNIPMORNpatients_elec',
#        'IPMORNIPMORNpatients_daycase', 'IPMORNIPMORNage_mean_elecnonelec',
#        'IPMORNIPMORNage_75plus_elecnonelec', 'year', 'month', 'dayofweek',
#        'flag_target_prevday', 'time', 'TARGET_prevday_lag6',
#        'TARGET_prevday_deriv1_lag7', 'TARGET_prevday_deriv2_lag7',
#        'TARGET_prevday_deriv1_lag14', 'TARGET_prevday_deriv2_lag14',
#        'EDDAILYattendances_deriv1_lag7', 'EDDAILYattendances_deriv2_lag7',
#        'EDDAILYattendances_deriv1_lag14', 'EDDAILYattendances_deriv2_lag14',
#        'EDDAILYadmissions_deriv1_lag7', 'EDDAILYadmissions_deriv2_lag7',
#        'EDDAILYadmissions_deriv1_lag14', 'EDDAILYadmissions_deriv2_lag14',
#        'EDDAILYage_75plus_deriv1_lag7', 'EDDAILYage_75plus_deriv2_lag7',
#        'EDDAILYage_75plus_deriv1_lag14', 'EDDAILYage_75plus_deriv2_lag14',
#        'IPDAILYpatients_nonelec_deriv1_lag7',
#        'IPDAILYpatients_nonelec_deriv2_lag7',
#        'IPDAILYpatients_nonelec_deriv1_lag14',
#        'IPDAILYpatients_nonelec_deriv2_lag14',
#        'IPDAILYpatients_elec_deriv1_lag7', 'IPDAILYpatients_elec_deriv2_lag7',
#        'IPDAILYpatients_elec_deriv1_lag14',
#        'IPDAILYpatients_elec_deriv2_lag14',
#        'IPDAILYpatients_daycase_deriv1_lag7',
#        'IPDAILYpatients_daycase_deriv2_lag7',
#        'IPDAILYpatients_daycase_deriv1_lag14',
#        'IPDAILYpatients_daycase_deriv2_lag14'],
#       dtype='object')

# %%
cat_features = ['month','dayofweek']
num_features = list(set(X_train.columns) - set(cat_features))
bin_features = []

# %% [markdown]
# #### find problem columns that will crash preprocessing pipleine when converting test data

# %%
problem_col_list = check_for_catagorical_type_difference_between_train_test(X_train, X_test, cat_features)

# %%
problem_col_list

# %% [markdown]
# Treat problem features as numerical so that process can continue.

# %% [markdown]
# - use sklearn pipelines to clean

# %%
# version 19.2
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder 

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

from src.data.preprocess import DataFrameSelector, MakeBooleanAnInteger

# %% [markdown]
# for col_name in cat_features:
#     values_list = X_train[col_name].unique()
#     for value in values_list:
#         print(col_name + '_' + str(value))

# %%
#### failed to get this to work as kept doubling size of output array. Didnt matter if get_col_list_for_after_pipeline fundtion was inside or outside of DataFrameReform class.


from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameReform(BaseEstimator,TransformerMixin):
    " Takes numpy array and forms into dataframe with column names."
    def __init__(self, new_features_list):
        self.new_features_list = new_features_list
    def fit(self, X, y=None):
        return self
    def transform(self,X):        
        return(pd.DataFrame(X, columns = self.new_features_list))

# %%
num_pipeline = Pipeline([
    ('selector',DataFrameSelector(num_features)),
    # lagger
    # derivative
    ('feature_filter',SelectKBest(f_classif,k='all')),
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

cat_pipeline = Pipeline([
    ('selector',DataFrameSelector(cat_features)),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('OneHot_encoder',OneHotEncoder(sparse=False))
])

bin_pipeline = Pipeline([
    ('selector',DataFrameSelector(bin_features)),
    ('boolean_conversion',MakeBooleanAnInteger()),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    #('encoding',LabelEncoder()),
])

# df_reform_pipeline = Pipeline([
#     ('reform_df', DataFrameReform(new_features_list))
# ])

#### create list of pipelines to include

pipes_list = [
    ('num_pipeline',num_pipeline),
  ('cat_pipeline',cat_pipeline),
#   ('bin_pipeline',bin_pipeline),
#     ('df_reform_pipeline', df_reform_pipeline)
]

full_pipeline = FeatureUnion(transformer_list=pipes_list
)


X_trainT = full_pipeline.fit_transform(X_train,y_train)
X_testT = full_pipeline.transform(X_test)

# %%
X_train.shape
# Out:
# (2093, 54)

# %%
X_trainT.shape
# Out:
# (2093, 71)

# %%
def get_col_list_for_after_pipeline(X, num_features, cat_features, bin_features):
    cat_features_new = []
    #### get new names for cat_features - must do here, otherwise when call fit transform the cat_features_new is appedned too twice.
#     print('TRANSFORM METHOD')
    for col_name in cat_features:
#         print('CAT FEATURES LOOP', col_name)
        values_list = X[col_name].unique()
        for value in values_list:
            cat_features_new.append(col_name + '_' + str(value))
#         print(cat_features_new)
    
    columns_list = num_features + cat_features_new + bin_features
#     print(len(columns_list))
    return(columns_list)

new_features_list = get_col_list_for_after_pipeline(X_train, num_features, cat_features, bin_features)

# %%
def reform_df(X, new_features_list):
    return(pd.DataFrame(X, columns= new_features_list))

X_trainT = reform_df(X_trainT, new_features_list)
X_testT = reform_df(X_testT, new_features_list)

# %%
X_testT.shape
# Out:
# (365, 71)

# %%
X_trainT.shape
# Out:
# (2093, 71)

# %%
X_testT.shape
# Out:
# (365, 71)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import classification_report,precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_curve,roc_curve
from sklearn.model_selection import TimeSeriesSplit

from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV



def find_best_model(model, grid, Xdata, ydata, plot_label):
    """does gridsearch for model and plots result from """
    my_cv = TimeSeriesSplit(n_splits=5).split(Xdata) # 5 chosen as gives roughly 1 year groups for each fold
    grid_search = GridSearchCV(model,grid,scoring='f1',cv=my_cv,return_train_score=True)
    grid_search.fit(Xdata,ydata)
    model = grid_search.best_estimator_
    print('CV MODEL RESULTS')
    print(grid_search.best_params_)
    print(pd.DataFrame(grid_search.cv_results_).query('rank_test_score == 1')[['mean_test_score','mean_train_score']])
    
#     plot_model_perf(ydata,Xdata,model,plot_label)

    
    return(grid_search)

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression(solver='liblinear',class_weight ='balanced')

# %%
grid = {'C':[0.01, 0.05, 0.1,0.2,0.3,0.5,0.7,1,3,10],
       'penalty':['l1','l2']}
# grid = {'C':[0.1]}

grid_search = find_best_model(lgr, grid, X_trainT, y_train, 'CV set')
# Out:
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#     mean_test_score  mean_train_score
# 10         0.532486          0.593559

# %%
data = grid_search.best_estimator_.coef_[0,:]
cols = list(X_trainT.columns)
important_features = pd.DataFrame(data=data, index=cols, columns=['coef']).sort_values('coef',ascending=False)

# %%
important_features.head(10)
# Out:
#                                           coef
# EDMORNoccupancy                       1.594088
# dayofweek_Tuesday                     1.203520
# IPDAILYpatients_nonelec_deriv1_lag14  0.781740
# IPMORNIPMORNage_75plus_elecnonelec    0.760009
# TARGET_prevday                        0.689855
# dayofweek_Wednesday                   0.530877
# IPMORNIPMORNpatients_total            0.510336
# month_12                              0.476366
# EDDAILYattendances                    0.271939
# IPDAILYage_mean_elecnonelec           0.235642

# %%
X_trainT.shape
# Out:
# (2093, 71)

# %%
y_train.shape
# Out:
# (2093,)

# %% [markdown]
# # finding perf on validation sets

# %%
X = X_trainT
y = y_train

# %%
from src.eval.eval_utils import BinClassEval

# %%
#### take model from earlier grid search
model = grid_search.best_estimator_

#### make cv timeseries generator
tscv = TimeSeriesSplit(n_splits=5)#.split(X_trainT)

#### loop over cv splits
loop_no = 0
for train_index, valid_index in tscv.split(X):
    loop_no += 1
    print(loop_no)
    
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    
    #### for this fold fit model
    model.fit(X_train, y_train)
    #### for this fold eval model
    print()
    BinClassEval(model, X_valid, y_valid, 'CV set number' + str(loop_no), plot=True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1
#
# Model has decision_function.
# Model has predict_proba.
# AUC:  0.917
# F1 score:  0.479
# accuracy:  0.675
# 2
#
# Model has decision_function.
# Model has predict_proba.
# AUC:  0.868
# F1 score:  0.49
# accuracy:  0.79
# 3
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Model has decision_function.
# Model has predict_proba.
# AUC:  0.912
# F1 score:  0.578
# accuracy:  0.891
# 4
#
# Model has decision_function.
# Model has predict_proba.
# AUC:  0.877
# F1 score:  0.576
# accuracy:  0.848
# 5
# No handles with labels found to put in legend.
# Model has decision_function.
# Model has predict_proba.
# AUC:  0.875
# F1 score:  0.54
# accuracy:  0.784

# %% [markdown]
# Conclusion:
#  - Issue with scores dropping off in larger data sets (i've seen this consistantly)
#      - is there a problem with X features? i.e. a massive drop off in the IP values (dont think so)
#      - long term trends affecting result. SO more data to train confuses things?
#  - we have an issue with using f1 score to choose a model, it doesnt represent the whole curve well. We could miss a robust model this way.
#  - number of folds makes a huge difference to curve

# %%
for i in X_valid.shape[0]:
    print(i)
# Out:
# IPDAILYage_75plus_elecnonelec
# EDDAILYattendances_deriv1_lag14
# IPDAILYage_mean_elecnonelec_deriv1_lag7
# IPDAILYpatients_nonelec_deriv2_lag14
# IPDAILYage_mean_elecnonelec_deriv2_lag14
# IPDAILYpatients_nonelec_deriv1_lag3
# IPDAILYpatients_nonelec_deriv2_lag1
# EDDAILYage_75plus_deriv1_lag3
# EDDAILYage_75plus_deriv1_lag5
# IPDAILYpatients_elec_deriv2_lag7
# EDDAILYadmissions_deriv2_lag5
# IPDAILYpatients_total_deriv2_lag3
# EDMORNoccupancy
# IPDAILYage_75plus_elecnonelec_deriv2_lag1
# IPMORNIPMORNpatients_total
# IPDAILYage_mean_elecnonelec_deriv1_lag14
# IPDAILYage_mean_elecnonelec_deriv1_lag5
# IPDAILYage_mean_elecnonelec_deriv2_lag5
# IPDAILYpatients_daycase_deriv1_lag30
# EDDAILYage_75plus_deriv2_lag5
# IPDAILYpatients_elec_deriv2_lag3
# IPDAILYpatients_total
# IPDAILYpatients_elec_deriv1_lag5
# EDDAILYage_75plus
# EDDAILYadmissions_deriv1_lag5
# IPDAILYpatients_nonelec_deriv2_lag30
# IPMORNIPMORNage_75plus_elecnonelec
# TARGET_prevday
# EDDAILYage_75plus_deriv2_lag3
# IPDAILYpatients_nonelec_deriv1_lag14
# IPDAILYpatients_nonelec_deriv1_lag30
# IPMORNIPMORNage_mean_elecnonelec
# IPDAILYage_mean_elecnonelec_deriv2_lag2
# IPDAILYpatients_daycase_deriv2_lag30
# IPDAILYpatients_nonelec
# month_1
# month_2
# month_3
# month_9
# month_12
# dayofweek_Monday
# dayofweek_Tuesday
# dayofweek_Friday
# dayofweek_Saturday

# %%
for col in list(X_valid.columns):
    X_valid[col].plot()

# %%
X_valid['EDMORNoccupancy'].plot(legend=False)

# %%
X_valid.plot(legend=False)

# %%
X_valid['IPDAILYpatients_nonelec'].plot()

# %%
for i in X_train.columns:
    print(i)
# Out:
# IPDAILYpatients_elec_deriv2_lag3
# EDDAILYage_mean
# TARGET_prevday_deriv1_lag1
# EDDAILYage_75plus_deriv1_lag5
# EDDAILYattendances_deriv1_lag7
# EDDAILYadmissions_deriv1_lag1
# IPDAILYage_75plus_elecnonelec_deriv2_lag3
# IPDAILYage_75plus_elecnonelec_deriv2_lag14
# IPMORNIPMORNpatients_total
# IPDAILYpatients_nonelec_deriv1_lag14
# IPDAILYpatients_daycase_deriv1_lag30
# EDDAILYage_mean_deriv1_lag5
# EDDAILYage_mean_deriv2_lag1
# EDDAILYage_mean_deriv1_lag30
# IPDAILYage_mean_elecnonelec_deriv2_lag14
# TARGET_prevday_lag27
# EDDAILYage_75plus_deriv1_lag2
# IPDAILYpatients_nonelec_deriv1_lag7
# IPDAILYpatients_daycase_deriv2_lag30
# TARGET_prevday_deriv1_lag3
# EDDAILYage_75plus_deriv2_lag7
# IPDAILYpatients_daycase
# TARGET_prevday
# IPDAILYpatients_total_deriv2_lag14
# IPDAILYpatients_elec_deriv1_lag14
# IPDAILYage_mean_elecnonelec_deriv2_lag30
# EDDAILYage_mean_deriv2_lag3
# IPMORNIPMORNage_mean_elecnonelec
# EDDAILYage_mean_deriv1_lag14
# EDDAILYage_75plus_deriv2_lag2
# IPDAILYpatients_elec_deriv1_lag30
# EDDAILYattendances_deriv1_lag5
# IPDAILYage_mean_elecnonelec_deriv2_lag7
# EDMORNoccupancy
# IPDAILYage_75plus_elecnonelec_deriv1_lag1
# TARGET_prevday_lag13
# IPDAILYpatients_nonelec_deriv2_lag3
# EDDAILYattendances_deriv1_lag3
# TARGET_prevday_deriv2_lag5
# EDDAILYattendances_deriv2_lag14
# EDDAILYadmissions_deriv1_lag5
# IPDAILYage_75plus_elecnonelec_deriv2_lag1
# EDDAILYadmissions_deriv1_lag14
# EDDAILYage_75plus_deriv1_lag14
# IPDAILYage_mean_elecnonelec_deriv1_lag3
# EDDAILYadmissions_deriv1_lag2
# EDDAILYage_75plus_deriv1_lag3
# IPDAILYpatients_total_deriv2_lag7
# TARGET_prevday_deriv1_lag5
# IPMORNIPMORNage_75plus_elecnonelec
# time
# IPDAILYpatients_daycase_deriv2_lag3
# IPDAILYpatients_total_deriv2_lag2
# IPDAILYage_75plus_elecnonelec_deriv2_lag7
# EDDAILYage_75plus_deriv2_lag1
# IPDAILYpatients_nonelec_deriv1_lag3
# EDDAILYage_mean_deriv1_lag2
# EDDAILYage_mean_deriv2_lag5
# IPDAILYpatients_nonelec_deriv2_lag2
# EDDAILYattendances_deriv1_lag14
# EDDAILYage_mean_deriv1_lag3
# IPDAILYpatients_elec_deriv2_lag5
# IPDAILYage_mean_elecnonelec_deriv2_lag2
# TARGET_prevday_deriv2_lag1
# TARGET_prevday_deriv1_lag2
# EDDAILYadmissions_deriv2_lag30
# IPDAILYpatients_elec
# EDDAILYage_75plus_deriv2_lag3
# EDDAILYattendances_deriv2_lag7
# EDDAILYage_75plus_deriv1_lag30
# IPMORNIPMORNpatients_nonelec
# IPDAILYpatients_total_deriv2_lag30
# EDMORNage_75plus
# EDDAILYattendances_deriv1_lag30
# IPDAILYpatients_total_deriv2_lag3
# IPDAILYage_mean_elecnonelec_deriv1_lag30
# EDDAILYage_mean_deriv2_lag2
# EDDAILYadmissions_deriv2_lag14
# IPDAILYpatients_daycase_deriv1_lag14
# IPDAILYpatients_nonelec_deriv2_lag30
# EDDAILYage_75plus_deriv1_lag1
# TARGET_prevday_deriv1_lag14
# EDDAILYage_75plus_deriv2_lag30
# IPDAILYage_mean_elecnonelec_deriv1_lag5
# EDDAILYage_mean_deriv2_lag14
# IPDAILYage_mean_elecnonelec_deriv1_lag7
# IPDAILYpatients_nonelec_deriv2_lag1
# IPDAILYpatients_nonelec
# EDDAILYattendances
# EDDAILYadmissions_deriv2_lag1
# EDDAILYage_75plus
# IPDAILYage_mean_elecnonelec_deriv1_lag2
# EDDAILYadmissions_deriv2_lag2
# IPDAILYpatients_elec_deriv2_lag30
# IPDAILYpatients_total
# IPMORNIPMORNpatients_elec
# EDDAILYage_mean_deriv2_lag30
# IPDAILYage_mean_elecnonelec_deriv2_lag3
# IPDAILYage_mean_elecnonelec_deriv2_lag5
# IPDAILYpatients_nonelec_deriv1_lag1
# flag_target_prevday
# IPDAILYage_75plus_elecnonelec_deriv1_lag5
# IPDAILYpatients_elec_deriv1_lag3
# EDDAILYattendances_deriv2_lag3
# IPDAILYage_75plus_elecnonelec_deriv1_lag7
# IPDAILYpatients_nonelec_deriv1_lag30
# IPDAILYpatients_elec_deriv1_lag5
# IPDAILYpatients_elec_deriv2_lag7
# IPDAILYpatients_nonelec_deriv2_lag14
# IPDAILYpatients_total_deriv1_lag30
# IPDAILYpatients_nonelec_deriv1_lag5
# IPDAILYage_mean_elecnonelec_deriv1_lag14
# year
# IPDAILYpatients_nonelec_deriv1_lag2
# IPDAILYage_75plus_elecnonelec
# EDDAILYadmissions_deriv2_lag5
# IPDAILYpatients_daycase_deriv1_lag5
# IPDAILYpatients_total_deriv1_lag3
# EDDAILYage_75plus_deriv2_lag5
# month_1
# month_2
# month_3
# month_4
# month_5
# month_6
# month_7
# month_8
# month_9
# month_11
# month_12
# dayofweek_Sunday
# dayofweek_Monday
# dayofweek_Tuesday
# dayofweek_Wednesday
# dayofweek_Thursday
# dayofweek_Friday
# dayofweek_Saturday

# %%
len(X_train)
# Out:
# 1727

# %%
len(y_train)
# Out:
# 1727

# %%
y.shape
# Out:
# (1727,)

# %%
y_valid.iloc[1720:]
# Out:
# Series([], Name: flag_target, dtype: int32)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-690fd14b1f64> in <module>
# ----> 1 BinClassEval(grid_search.best_estimator_, X_valid, y_valid)
#
# ~\OneDrive - University of Southampton\MH028_UHS_Weather\4_Analysis\EDclassification\src\eval\eval_utils.py in __init__(self, model, X, y, plot_title, plot)
#      40         ### NOTE: these are assigned to the same proba_preds attribute. If predict_prob avail then this takes precident.
#      41         if hasattr(model, 'decision_function'):
# ---> 42             predDF = model.decision_function(X) # warning, some model dont have DF
#      43             self.proba_preds = predDF
#      44             self.DF = predDF
#
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     268         if X.shape[1] != n_features:
#     269             raise ValueError("X has %d features per sample; expecting %d"
# --> 270                              % (X.shape[1], n_features))
#     271
#     272         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 137 features per sample; expecting 146

# %%
break
# Out:
#   File "<ipython-input-54-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %%
# %matplotlib inline
scores_history.plot()

# %%
# %matplotlib inline
scores_history.plot()

# %%
# %matplotlib inline
scores_history.plot()

# %%
#### make copy o feature data
X_trainTD = X_trainT.copy()
no_features = X_trainTD.shape[1]

mean_test_score = []
mean_train_score = []
number_features = []

# for loop in np.arange(0,10):
while no_features > 35:
    number_features.append(no_features)
    grid = {
        'C':[0.05, 0.1,0.2,0.3,0.5,0.7,1],
       'penalty':['l1'] # 'l1',
    }
    
    #### train model
    grid_search = find_best_model(lgr, grid, X_trainTD, y_train, 'CV set')
    
    #### find feature importance
    data = grid_search.best_estimator_.coef_[0,:]
    cols = list(X_trainTD.columns)
    important_features = pd.DataFrame(data=data, index=cols, columns=['coef'])
    important_features['coef'] = important_features.coef.abs()
    important_features = important_features.sort_values('coef',ascending=False)
    
    #### save/print info
    no_features = X_trainTD.shape[1]
    print('No. features: ' , no_features)
    
    scores_df = (pd.DataFrame(grid_search.cv_results_).query('rank_test_score == 1')[['mean_test_score','mean_train_score']])
    
    mean_test_score.append(scores_df.mean_test_score.values[0])
    mean_train_score.append(scores_df.mean_train_score.values[0])
    
    #### find features to remove
    col_to_drop = []
#     col_to_drop = list(important_features[(important_features["coef"] < 0.001)].index)
    if len(col_to_drop) == 0:
        col_to_drop = list(important_features[-1:].index)
    
    #### remove features
    X_trainTD = X_trainTD.drop(col_to_drop,axis=1)
    

    
data = {'mean_test_score':mean_test_score, 'mean_train_score':mean_train_score, 'number_features':number_features}
scores_history = pd.DataFrame(data).set_index('number_features')
# Out:
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  190
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  189
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  188
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  187
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  186
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  185
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  184
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  183
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084          0.535958
# No. features:  182
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450084           0.53685
# No. features:  181
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450479           0.53685
# No. features:  180
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450879           0.53685
# No. features:  179
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450479           0.53685
# No. features:  178
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450479           0.53685
# No. features:  177
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450879           0.53685
# No. features:  176
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450879           0.53685
# No. features:  175
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.454221           0.56294
# No. features:  174
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.454221           0.56294
# No. features:  173
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.454221           0.56294
# No. features:  172
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.454221          0.562259
# No. features:  171
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.454221           0.56294
# No. features:  170
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.455179          0.561321
# No. features:  169
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2          0.45204          0.561479
# No. features:  168
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.452599          0.561479
# No. features:  167
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.452599          0.560995
# No. features:  166
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.453064          0.560173
# No. features:  165
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.453064          0.560173
# No. features:  164
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.452599            0.5609
# No. features:  163
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.453629          0.561582
# No. features:  162
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.449449          0.562424
# No. features:  161
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.449915          0.562424
# No. features:  160
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.449915          0.562424
# No. features:  159
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.449306          0.529369
# No. features:  158
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.448884          0.563036
# No. features:  157
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2          0.44935          0.563548
# No. features:  156
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2          0.44935          0.563548
# No. features:  155
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448875          0.529898
# No. features:  154
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448875          0.530031
# No. features:  153
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448875          0.529898
# No. features:  152
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448875          0.530031
# No. features:  151
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529898
# No. features:  150
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529292
# No. features:  149
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529292
# No. features:  148
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529292
# No. features:  147
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529292
# No. features:  146
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.448359          0.529292
# No. features:  145
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.450671          0.529558
# No. features:  144
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.451405          0.523053
# No. features:  143
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.451405          0.522378
# No. features:  142
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.451405            0.5223
# No. features:  141
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.451405          0.522166
# No. features:  140
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.451565          0.553656
# No. features:  139
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.451991          0.553656
# No. features:  138
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.452726          0.522209
# No. features:  137
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.452726          0.522209
# No. features:  136
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.452726          0.522375
# No. features:  135
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.452726          0.522375
# No. features:  134
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.453122          0.521234
# No. features:  133
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.453122          0.521234
# No. features:  132
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.452726          0.521234
# No. features:  131
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.453681          0.521752
# No. features:  130
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.453681          0.521752
# No. features:  129
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523903
# No. features:  128
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523903
# No. features:  127
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  126
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  125
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  124
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  123
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  122
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.455736          0.523424
# No. features:  121
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  120
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  119
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  118
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  117
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  116
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  115
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  114
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  113
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  112
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  111
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  110
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  109
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  108
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  107
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  106
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  105
# CV MODEL RESULTS
# {'C': 0.1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 1         0.456784          0.523302
# No. features:  104
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.453917          0.577571
# No. features:  103
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.451981          0.592929
# No. features:  102
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5          0.45059          0.591704
# No. features:  101
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.452128          0.592536
# No. features:  100
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.450629          0.592679
# No. features:  99
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.449823          0.561116
# No. features:  98
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3          0.45247          0.560409
# No. features:  97
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3          0.45247          0.561009
# No. features:  96
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.453495          0.561009
# No. features:  95
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.450759           0.55919
# No. features:  94
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.456129           0.56157
# No. features:  93
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.457709          0.560766
# No. features:  92
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.456798           0.56049
# No. features:  91
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.456798          0.560844
# No. features:  90
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.457253          0.557629
# No. features:  89
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455478          0.558023
# No. features:  88
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3           0.4549          0.558023
# No. features:  87
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455462          0.559768
# No. features:  86
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455462          0.559768
# No. features:  85
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.457534          0.559581
# No. features:  84
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.457534          0.559581
# No. features:  83
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.456259          0.545269
# No. features:  82
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.456259          0.545269
# No. features:  81
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.456259          0.545269
# No. features:  80
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.457691          0.559799
# No. features:  79
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.455499          0.544592
# No. features:  78
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.455499          0.544592
# No. features:  77
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.455499          0.544225
# No. features:  76
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455795          0.558135
# No. features:  75
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455795          0.558272
# No. features:  74
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.454708          0.556223
# No. features:  73
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.455245           0.55588
# No. features:  72
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3          0.45617           0.55577
# No. features:  71
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.458282          0.579522
# No. features:  70
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.464357           0.55891
# No. features:  69
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.465024          0.559537
# No. features:  68
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.465024          0.559537
# No. features:  67
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.465024          0.559537
# No. features:  66
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.465024          0.559537
# No. features:  65
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.465826          0.577486
# No. features:  64
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.467497          0.577781
# No. features:  63
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.472483          0.577076
# No. features:  62
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.467016           0.57637
# No. features:  61
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3          0.46575          0.558701
# No. features:  60
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.468684          0.561194
# No. features:  59
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.470909          0.568516
# No. features:  58
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6          0.46936          0.575713
# No. features:  57
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.471796          0.574278
# No. features:  56
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4          0.46296          0.558268
# No. features:  55
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.463186          0.553064
# No. features:  54
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.470523          0.560386
# No. features:  53
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.467867          0.567484
# No. features:  52
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.470008          0.568887
# No. features:  51
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4          0.46743          0.557838
# No. features:  50
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.466356          0.557698
# No. features:  49
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.470298          0.566028
# No. features:  48
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.475317          0.568871
# No. features:  47
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.471489          0.563512
# No. features:  46
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.475263          0.558928
# No. features:  45
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.474031          0.559201
# No. features:  44
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.470142          0.558041
# No. features:  43
# CV MODEL RESULTS
# {'C': 0.5, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 4         0.470641          0.557937
# No. features:  42
# CV MODEL RESULTS
# {'C': 0.7, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 5         0.469432          0.558769
# No. features:  41
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.470088          0.534381
# No. features:  40
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.468766          0.533967
# No. features:  39
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.470745          0.533946
# No. features:  38
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 3         0.480675          0.542179
# No. features:  37
# CV MODEL RESULTS
# {'C': 0.2, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 2         0.476464          0.530429
# No. features:  36
# CV MODEL RESULTS
# {'C': 1, 'penalty': 'l1'}
#    mean_test_score  mean_train_score
# 6         0.485602          0.551784
# No. features:  35

# %%
scores_history.plot()

# %%
important_features
# Out:
#                                                coef
# dayofweek_Tuesday                          1.474057
# month_9                                    1.220660
# TARGET_prevday                             0.988190
# month_6                                    0.501065
# IPDAILYpatients_nonelec_deriv2_lag1        0.485647
# IPDAILYpatients_daycase_deriv1_lag5        0.466849
# IPDAILYpatients_daycase_deriv2_lag2        0.457718
# month_7                                    0.429526
# IPDAILYpatients_daycase_deriv2_lag30       0.417727
# IPDAILYpatients_daycase_deriv2_lag3        0.398600
# IPDAILYpatients_elec_deriv2_lag3           0.398206
# IPDAILYpatients_nonelec_deriv1_lag30       0.348926
# month_4                                    0.338480
# EDDAILYage_75plus_deriv2_lag3              0.317721
# EDDAILYattendances_deriv1_lag14            0.313154
# EDDAILYadmissions_deriv2_lag1              0.310946
# year                                       0.306326
# month_12                                   0.279994
# EDDAILYadmissions_deriv2_lag5              0.272661
# IPDAILYpatients_nonelec_deriv2_lag30       0.257186
# EDDAILYadmissions_deriv1_lag3              0.245899
# IPDAILYpatients_nonelec_deriv1_lag7        0.244964
# IPDAILYage_mean_elecnonelec_deriv2_lag30   0.244721
# IPDAILYage_75plus_elecnonelec_deriv2_lag7  0.225292
# IPDAILYpatients_nonelec_deriv1_lag3        0.218091
# IPDAILYage_mean_elecnonelec_deriv2_lag5    0.209752
# TARGET_prevday_deriv2_lag30                0.205634
# TARGET_prevday_deriv2_lag14                0.201226
# IPDAILYage_75plus_elecnonelec_deriv2_lag1  0.198938
# EDDAILYadmissions_deriv1_lag14             0.178148
# EDDAILYage_mean_deriv1_lag14               0.174946
# IPDAILYpatients_daycase_deriv1_lag14       0.170053
# TARGET_prevday_deriv1_lag1                 0.167974
# TARGET_prevday_lag13                       0.148583
# IPDAILYpatients_elec_deriv2_lag14          0.139139

# %%
break
# Out:
#   File "<ipython-input-39-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %% [markdown]
# NOTE: consider creating log for preprocessing information in order for repeatability in future.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', lgr, grid_search, 'Uses all features + derivatives from previous day. l1 pen iterated over all variables to reduce number of vars. in D2_daily_data_to_model_FULLPIPELINE_find best features.ipynb.')
# Out:
# Model logged.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', lgr, grid_search, 'Uses all features + derivatives from previous day. l2 pen iterated over all variables (rm coef < 0.05 or 1) to reduce number of vars. in D2_daily_data_to_model_FULLPIPELINE_find best features.ipynb.')
# Out:
# Model logged.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', rf, grid_search, 'Model uses all derivative features from previous day. in D2_daily_data_to_model_FULLPIPELINE.ipynb.')
# Out:
# Model logged.

# %%
models = pd.read_pickle('./../../data/output/model_log.pkl')
# models.drop(3,inplace=True)
models
# Out:
#   dataV                                              model  \
# 0    v1  LogisticRegression(C=0.3, class_weight='balanc...
# 1    v1  (DecisionTreeClassifier(class_weight=None, cri...
# 2    v1  XGBClassifier(base_score=0.5, booster='gbtree'...
# 3    D2  RandomForestClassifier(bootstrap=True, class_w...
# 4    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 5    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 6    D2  LogisticRegression(C=1.0, class_weight='balanc...
# 7    D2  LogisticRegression(C=1.0, class_weight='balanc...
#
#                                           gridsearch mean_train mean_valid  \
# 0     mean_fit_time  std_fit_time  mean_score_tim...    [0.629]     [0.52]
# 1      mean_fit_time  std_fit_time  mean_score_ti...    [0.685]    [0.419]
# 2     mean_fit_time  std_fit_time  mean_score_tim...    [0.829]    [0.439]
# 3     mean_fit_time  std_fit_time  mean_score_tim...     [0.64]    [0.454]
# 4      mean_fit_time  std_fit_time  mean_score_ti...    [0.489]    [0.445]
# 5      mean_fit_time  std_fit_time  mean_score_ti...    [0.515]    [0.448]
# 6     mean_fit_time  std_fit_time  mean_score_tim...    [0.552]    [0.486]
# 7     mean_fit_time  std_fit_time  mean_score_tim...    [0.577]    [0.494]
#
#                                                notes
# 0  Initial model which was built on first edition...
# 1                 Random Forest 1st attempt with v1.
# 2  V1 attempt with XGBOOST. KFOLD selection of fe...
# 3  Model uses all derivative features from previo...
# 4  Model uses all derivative features from previo...
# 5  only target features from previous day + der+l...
# 6  Uses all features + derivatives from previous ...
# 7  Uses all features + derivatives from previous ...

# %%
models.to_pickle('./../../data/output/model_log.pkl')
