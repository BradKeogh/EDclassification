# %% [markdown]
# # Notebook used to help create:
#
# - importing data src
# - precprocessing data src

# %%
# %pwd
# Out:
# 'C:\\Users\\bjk1y13\\OneDrive - University of Southampton\\MH028_UHS_Weather\\4_Analysis\\EDclassification\\notebooks\\model'

# %%
import pandas as pd
import numpy as np
from src.data.io import import_pickled_feature_dfs, import_merge_prevday_target_column, import_merge_pickled_target_class

# %% [markdown]
# # Import data

# %%
features = import_pickled_feature_dfs('../../data/interim/D2_timeseries/', ['EDdaily.pkl', 'IPdaily.pkl', 'callender.pkl'])

# %%
features.shape
# Out:
# (2465, 13)

# %%
features.tail()
# Out:
#            EDDAILYattendances EDDAILYadmissions EDDAILYage_mean  \
#
# 2018-09-26                446               182         42.9126
# 2018-09-27                487               188         44.7064
# 2018-09-28                482               168         44.1992
# 2018-09-29                463               191         46.4989
# 2018-09-30                367               157         40.3597
#
#            EDDAILYage_75plus IPDAILYpatients_total IPDAILYpatients_nonelec  \
#
# 2018-09-26                62                     2                       1
# 2018-09-27                82                     2                       1
# 2018-09-28                74                     2                       1
# 2018-09-29                84                     1                       0
# 2018-09-30                47                     1                       0
#
#            IPDAILYpatients_elec IPDAILYpatients_daycase  \
#
# 2018-09-26                    1                       0
# 2018-09-27                    1                       0
# 2018-09-28                    1                       0
# 2018-09-29                    1                       0
# 2018-09-30                    1                       0
#
#            IPDAILYage_mean_elecnonelec IPDAILYage_75plus_elecnonelec  year  \
#
# 2018-09-26                        35.5                             0  2018
# 2018-09-27                        35.5                             0  2018
# 2018-09-28                        35.5                             0  2018
# 2018-09-29                           0                             0  2018
# 2018-09-30                           0                             0  2018
#
#             month  dayofweek
#
# 2018-09-26      9  Wednesday
# 2018-09-27      9   Thursday
# 2018-09-28      9     Friday
# 2018-09-29      9   Saturday
# 2018-09-30      9     Sunday

# %%
target = pd.read_pickle('../../data/interim/EDooc_class.pkl')

# %%
features = target.merge(features, right_index=True, left_index=True)

# %% [markdown]
# Remember target does not need to be offset because features were calculated for the previous days records

# %%
features_final = features.copy()
# features_final['flag_target'] = features_final['flag_target'].shift(-1)
##### we do shift the EDocc col as this is for the current date in index.
features_final['EDocc'] = features_final['EDocc'].shift(1)

# %%
features_final.rename(columns={'EDocc':'TARGET_prevday'},inplace=True)

# %%
features_final['flag_target_prevday'] = features_final['flag_target'].shift(1)

# %%
features_final.flag_target.value_counts()
# Out:
# 0    2094
# 1     371
# Name: flag_target, dtype: int64

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-01             NaN            1                NaN               NaN
# 2012-01-02       55.750000            0                377               151
# 2012-01-03       38.541667            0                350               139
# 2012-01-04       40.208333            0                356               125
# 2012-01-05       32.375000            0                284                92
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-01             NaN               NaN                   NaN
# 2012-01-02         40.0186                59                  1185
# 2012-01-03         42.2114                44                  1228
# 2012-01-04         45.1011                58                  1564
# 2012-01-05         42.5035                49                  1535
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-01                     NaN                  NaN
# 2012-01-02                    1001                  141
# 2012-01-03                    1037                  141
# 2012-01-04                    1074                  208
# 2012-01-05                    1066                  241
#
#            IPDAILYpatients_daycase IPDAILYage_mean_elecnonelec  \
# dt_date
# 2012-01-01                     NaN                         NaN
# 2012-01-02                      43                     57.3814
# 2012-01-03                      50                     57.4292
# 2012-01-04                     282                     55.5352
# 2012-01-05                     228                     55.4072
#
#            IPDAILYage_75plus_elecnonelec  year  month  dayofweek  \
# dt_date
# 2012-01-01                           NaN  2012      1     Sunday
# 2012-01-02                           441  2012      1     Monday
# 2012-01-03                           453  2012      1    Tuesday
# 2012-01-04                           475  2012      1  Wednesday
# 2012-01-05                           482  2012      1   Thursday
#
#             flag_target_prevday
# dt_date
# 2012-01-01                  NaN
# 2012-01-02                  1.0
# 2012-01-03                  0.0
# 2012-01-04                  0.0
# 2012-01-05                  0.0

# %%
features_final.columns
# Out:
# Index(['TARGET_prevday', 'flag_target', 'EDDAILYattendances',
#        'EDDAILYadmissions', 'EDDAILYage_mean', 'EDDAILYage_75plus',
#        'IPDAILYpatients_total', 'IPDAILYpatients_nonelec',
#        'IPDAILYpatients_elec', 'IPDAILYpatients_daycase',
#        'IPDAILYage_mean_elecnonelec', 'IPDAILYage_75plus_elecnonelec', 'year',
#        'month', 'dayofweek', 'flag_target_prevday'],
#       dtype='object')

# %% [markdown]
# IP occ data after 2018-5-31 is not valid. NOTE: must check if that is same in RAW.

# %% [markdown]
# ## Add new lagged and derivative features

# %%
from src.features.feature_gen import create_lagged_vars_list

features_final = create_lagged_vars_list(features_final, 'TARGET_prevday', [6,13,27])

# %%
from src.features.feature_gen import perform_deriv_cals_multiple_columns

# %%
lags_required = {
                'TARGET_prevday':[1,2,3,5,7,14,30],
#                  'EDDAILYattendances':[1,2,3,5,7,14,30],
#                 'EDDAILYadmissions':[1,2,3,5,7,14,30],
#                  'EDDAILYage_mean':[1,2,3,5,7,14,30], 
#                 'EDDAILYage_75plus':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_total':[1,2,3,5,7,14,30],
                 'IPDAILYpatients_nonelec':[1,2,3,5,7,14,30],
#                  'IPDAILYpatients_elec':[1,2,3,5,7,14,30],
                 'IPDAILYpatients_daycase':[1,30],
#                  'IPDAILYage_mean_elecnonelec':[1,2,3,5,7,14,30],
#                  'IPDAILYage_75plus_elecnonelec':[1,2,3,5,7,14,30],
                 
                
                }
features_final = perform_deriv_cals_multiple_columns(features_final, lags_required, 2)

# %%
features_final.head()
# Out:
#             TARGET_prevday  flag_target EDDAILYattendances EDDAILYadmissions  \
# dt_date
# 2012-01-29       35.625000            0                307               129
# 2012-01-30       38.083333            0                326               128
# 2012-01-31       38.916667            0                348               120
# 2012-02-01       41.208333            0                367               153
# 2012-02-02       43.083333            0                359               121
#
#            EDDAILYage_mean EDDAILYage_75plus IPDAILYpatients_total  \
# dt_date
# 2012-01-29          41.329                59                  1248
# 2012-01-30         36.2055                40                  1238
# 2012-01-31         40.5718                46                  1491
# 2012-02-01         41.7984                57                  1594
# 2012-02-02         39.6992                46                  1460
#
#            IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# dt_date
# 2012-01-29                     916                  264
# 2012-01-30                     923                  250
# 2012-01-31                     957                  317
# 2012-02-01                     966                  333
# 2012-02-02                     957                  329
#
#            IPDAILYpatients_daycase  ... IPDAILYpatients_nonelec_deriv1_lag7  \
# dt_date                             ...
# 2012-01-29                      68  ...                                -1.0
# 2012-01-30                      65  ...                                -1.0
# 2012-01-31                     217  ...                                -1.0
# 2012-02-01                     295  ...                                -1.0
# 2012-02-02                     174  ...                                -1.0
#
#            IPDAILYpatients_nonelec_deriv2_lag7  \
# dt_date
# 2012-01-29                                57.0
# 2012-01-30                                57.0
# 2012-01-31                                57.0
# 2012-02-01                                57.0
# 2012-02-02                                57.0
#
#             IPDAILYpatients_nonelec_deriv1_lag14  \
# dt_date
# 2012-01-29                                  55.0
# 2012-01-30                                  55.0
# 2012-01-31                                  55.0
# 2012-02-01                                  55.0
# 2012-02-02                                  55.0
#
#             IPDAILYpatients_nonelec_deriv2_lag14  \
# dt_date
# 2012-01-29                                 -80.0
# 2012-01-30                                 -80.0
# 2012-01-31                                 -80.0
# 2012-02-01                                 -80.0
# 2012-02-02                                 -80.0
#
#            IPDAILYpatients_nonelec_deriv1_lag30  \
# dt_date
# 2012-01-29                                126.0
# 2012-01-30                                126.0
# 2012-01-31                                126.0
# 2012-02-01                                126.0
# 2012-02-02                                126.0
#
#             IPDAILYpatients_nonelec_deriv2_lag30  \
# dt_date
# 2012-01-29                                -214.0
# 2012-01-30                                -214.0
# 2012-01-31                                -214.0
# 2012-02-01                                -214.0
# 2012-02-02                                -214.0
#
#             IPDAILYpatients_daycase_deriv1_lag1  \
# dt_date
# 2012-01-29                                 -3.0
# 2012-01-30                                 -3.0
# 2012-01-31                                152.0
# 2012-02-01                                 78.0
# 2012-02-02                               -121.0
#
#             IPDAILYpatients_daycase_deriv2_lag1  \
# dt_date
# 2012-01-29                                155.0
# 2012-01-30                                155.0
# 2012-01-31                                155.0
# 2012-02-01                                -74.0
# 2012-02-02                               -199.0
#
#             IPDAILYpatients_daycase_deriv1_lag30  \
# dt_date
# 2012-01-29                                 183.0
# 2012-01-30                                 183.0
# 2012-01-31                                 183.0
# 2012-02-01                                 183.0
# 2012-02-02                                 183.0
#
#             IPDAILYpatients_daycase_deriv2_lag30
# dt_date
# 2012-01-29                                -150.0
# 2012-01-30                                -150.0
# 2012-01-31                                -150.0
# 2012-02-01                                -150.0
# 2012-02-02                                -150.0
#
# [5 rows x 51 columns]

# %% [markdown]
# ## check and remove nans

# %%
features_final.isnull().sum()
# Out:
# TARGET_prevday                          0
# flag_target                             0
# EDDAILYattendances                      0
# EDDAILYadmissions                       0
# EDDAILYage_mean                         0
# EDDAILYage_75plus                       0
# IPDAILYpatients_total                   0
# IPDAILYpatients_nonelec                 0
# IPDAILYpatients_elec                    0
# IPDAILYpatients_daycase                 0
# IPDAILYage_mean_elecnonelec             0
# IPDAILYage_75plus_elecnonelec           0
# year                                    0
# month                                   0
# dayofweek                               0
# flag_target_prevday                     0
# TARGET_prevday_lag6                     0
# TARGET_prevday_lag13                    0
# TARGET_prevday_lag27                    0
# TARGET_prevday_deriv1_lag1              0
# TARGET_prevday_deriv2_lag1              0
# TARGET_prevday_deriv1_lag2              0
# TARGET_prevday_deriv2_lag2              0
# TARGET_prevday_deriv1_lag3              0
# TARGET_prevday_deriv2_lag3              0
# TARGET_prevday_deriv1_lag5              0
# TARGET_prevday_deriv2_lag5              0
# TARGET_prevday_deriv1_lag7              0
# TARGET_prevday_deriv2_lag7              0
# TARGET_prevday_deriv1_lag14             0
# TARGET_prevday_deriv2_lag14             0
# TARGET_prevday_deriv1_lag30             0
# TARGET_prevday_deriv2_lag30             0
# IPDAILYpatients_nonelec_deriv1_lag1     0
# IPDAILYpatients_nonelec_deriv2_lag1     0
# IPDAILYpatients_nonelec_deriv1_lag2     0
# IPDAILYpatients_nonelec_deriv2_lag2     0
# IPDAILYpatients_nonelec_deriv1_lag3     0
# IPDAILYpatients_nonelec_deriv2_lag3     0
# IPDAILYpatients_nonelec_deriv1_lag5     0
# IPDAILYpatients_nonelec_deriv2_lag5     0
# IPDAILYpatients_nonelec_deriv1_lag7     0
# IPDAILYpatients_nonelec_deriv2_lag7     0
# IPDAILYpatients_nonelec_deriv1_lag14    0
# IPDAILYpatients_nonelec_deriv2_lag14    0
# IPDAILYpatients_nonelec_deriv1_lag30    0
# IPDAILYpatients_nonelec_deriv2_lag30    0
# IPDAILYpatients_daycase_deriv1_lag1     0
# IPDAILYpatients_daycase_deriv2_lag1     0
# IPDAILYpatients_daycase_deriv1_lag30    0
# IPDAILYpatients_daycase_deriv2_lag30    0
# dtype: int64

# %%
features_final.dropna(inplace=True)

# %% [markdown]
# # Processing
#
# #### split test and train sets

# %%
from src.data.preprocess import make_timeseries_test_train_splits

# %%
X_train, X_test, y_train, y_test = make_timeseries_test_train_splits(features_final, 'flag_target', 365)
# Out:
# DATA POINTS:
# orig size 2437
# training:  2072
# testing:  365

# %%
from src.data.preprocess import get_variable_types_lists, check_for_catagorical_type_difference_between_train_test, change_feature_types_to_numeric
    

# num_features, cat_features, bin_features = get_variable_types_lists(X_train)

# %%
X_train.columns
# Out:
# Index(['TARGET_prevday', 'EDDAILYattendances', 'EDDAILYadmissions',
#        'EDDAILYage_mean', 'EDDAILYage_75plus', 'IPDAILYpatients_total',
#        'IPDAILYpatients_nonelec', 'IPDAILYpatients_elec',
#        'IPDAILYpatients_daycase', 'IPDAILYage_mean_elecnonelec',
#        'IPDAILYage_75plus_elecnonelec', 'year', 'month', 'dayofweek',
#        'flag_target_prevday', 'TARGET_prevday_lag6', 'TARGET_prevday_lag13',
#        'TARGET_prevday_lag27', 'TARGET_prevday_deriv1_lag1',
#        'TARGET_prevday_deriv2_lag1', 'TARGET_prevday_deriv1_lag2',
#        'TARGET_prevday_deriv2_lag2', 'TARGET_prevday_deriv1_lag3',
#        'TARGET_prevday_deriv2_lag3', 'TARGET_prevday_deriv1_lag5',
#        'TARGET_prevday_deriv2_lag5', 'TARGET_prevday_deriv1_lag7',
#        'TARGET_prevday_deriv2_lag7', 'TARGET_prevday_deriv1_lag14',
#        'TARGET_prevday_deriv2_lag14', 'TARGET_prevday_deriv1_lag30',
#        'TARGET_prevday_deriv2_lag30', 'IPDAILYpatients_nonelec_deriv1_lag1',
#        'IPDAILYpatients_nonelec_deriv2_lag1',
#        'IPDAILYpatients_nonelec_deriv1_lag2',
#        'IPDAILYpatients_nonelec_deriv2_lag2',
#        'IPDAILYpatients_nonelec_deriv1_lag3',
#        'IPDAILYpatients_nonelec_deriv2_lag3',
#        'IPDAILYpatients_nonelec_deriv1_lag5',
#        'IPDAILYpatients_nonelec_deriv2_lag5',
#        'IPDAILYpatients_nonelec_deriv1_lag7',
#        'IPDAILYpatients_nonelec_deriv2_lag7',
#        'IPDAILYpatients_nonelec_deriv1_lag14',
#        'IPDAILYpatients_nonelec_deriv2_lag14',
#        'IPDAILYpatients_nonelec_deriv1_lag30',
#        'IPDAILYpatients_nonelec_deriv2_lag30',
#        'IPDAILYpatients_daycase_deriv1_lag1',
#        'IPDAILYpatients_daycase_deriv2_lag1',
#        'IPDAILYpatients_daycase_deriv1_lag30',
#        'IPDAILYpatients_daycase_deriv2_lag30'],
#       dtype='object')

# %%
cat_features = ['month','dayofweek']
num_features = list(set(X_train.columns) - set(cat_features))
bin_features = []

# %% [markdown]
# #### find problem columns that will crash preprocessing pipleine when converting test data

# %%
problem_col_list = check_for_catagorical_type_difference_between_train_test(X_train, X_test, cat_features)

# %%
problem_col_list

# %% [markdown]
# Treat problem features as numerical so that process can continue.

# %% [markdown]
# - use sklearn pipelines to clean

# %%
# version 19.2
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder 

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

from src.data.preprocess import DataFrameSelector, MakeBooleanAnInteger

# %% [markdown]
# for col_name in cat_features:
#     values_list = X_train[col_name].unique()
#     for value in values_list:
#         print(col_name + '_' + str(value))

# %%
#### failed to get this to work as kept doubling size of output array. Didnt matter if get_col_list_for_after_pipeline fundtion was inside or outside of DataFrameReform class.


from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameReform(BaseEstimator,TransformerMixin):
    " Takes numpy array and forms into dataframe with column names."
    def __init__(self, new_features_list):
        self.new_features_list = new_features_list
    def fit(self, X, y=None):
        return self
    def transform(self,X):        
        return(pd.DataFrame(X, columns = self.new_features_list))

# %%
num_pipeline = Pipeline([
    ('selector',DataFrameSelector(num_features)),
    # lagger
    # derivative
    ('feature_filter',SelectKBest(f_classif,k='all')),
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

cat_pipeline = Pipeline([
    ('selector',DataFrameSelector(cat_features)),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('OneHot_encoder',OneHotEncoder(sparse=False))
])

bin_pipeline = Pipeline([
    ('selector',DataFrameSelector(bin_features)),
    ('boolean_conversion',MakeBooleanAnInteger()),
    ('imputer',SimpleImputer(strategy='most_frequent')),
    #('encoding',LabelEncoder()),
])

# df_reform_pipeline = Pipeline([
#     ('reform_df', DataFrameReform(new_features_list))
# ])

#### create list of pipelines to include

pipes_list = [
    ('num_pipeline',num_pipeline),
  ('cat_pipeline',cat_pipeline),
#   ('bin_pipeline',bin_pipeline),
#     ('df_reform_pipeline', df_reform_pipeline)
]

full_pipeline = FeatureUnion(transformer_list=pipes_list
)


X_trainT = full_pipeline.fit_transform(X_train,y_train)
X_testT = full_pipeline.transform(X_test)

# %%
X_train.shape
# Out:
# (2072, 50)

# %%
X_trainT.shape
# Out:
# (2072, 67)

# %%
def get_col_list_for_after_pipeline(X, num_features, cat_features, bin_features):
    cat_features_new = []
    #### get new names for cat_features - must do here, otherwise when call fit transform the cat_features_new is appedned too twice.
#     print('TRANSFORM METHOD')
    for col_name in cat_features:
#         print('CAT FEATURES LOOP', col_name)
        values_list = X[col_name].unique()
        for value in values_list:
            cat_features_new.append(col_name + '_' + str(value))
#         print(cat_features_new)
    
    columns_list = num_features + cat_features_new + bin_features
#     print(len(columns_list))
    return(columns_list)

new_features_list = get_col_list_for_after_pipeline(X_train, num_features, cat_features, bin_features)

# %%
def reform_df(X, new_features_list):
    return(pd.DataFrame(X, columns= new_features_list))

X_trainT = reform_df(X_trainT, new_features_list)
X_testT = reform_df(X_testT, new_features_list)

# %%
X_testT.shape
# Out:
# (365, 67)

# %%
X_trainT.shape
# Out:
# (2072, 67)

# %%
X_testT.shape
# Out:
# (365, 67)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import classification_report,precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_curve,roc_curve
from sklearn.model_selection import TimeSeriesSplit

from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV



def find_best_model(model, grid, Xdata, ydata, plot_label):
    """does gridsearch for model and plots result from """
    my_cv = TimeSeriesSplit(n_splits=5).split(Xdata) # 5 chosen as gives roughly 1 year groups for each fold
    grid_search = GridSearchCV(model,grid,scoring='f1',cv=my_cv,return_train_score=True)
    grid_search.fit(Xdata,ydata)
    model = grid_search.best_estimator_
    print('CV MODEL RESULTS')
    print(grid_search.best_params_)
    print(pd.DataFrame(grid_search.cv_results_).query('rank_test_score == 1')[['mean_test_score','mean_train_score']])
    
#     plot_model_perf(ydata,Xdata,model,plot_label)

    
    return(grid_search)

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression(solver='liblinear',class_weight ='balanced')

# %%
grid = {'C':[0.01, 0.05, 0.1,0.2,0.3,0.5,0.7,1,3,10],
       'penalty':['l1','l2']}
# grid = {'C':[0.1]}

grid_search = find_best_model(lgr, grid, X_trainT, y_train, 'CV set')
# Out:
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Anaconda3\envs\EDclass\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# CV MODEL RESULTS
# {'C': 0.3, 'penalty': 'l2'}
#    mean_test_score  mean_train_score
# 9         0.444687          0.542089

# %%
data = grid_search.best_estimator_.coef_[0,:]
cols = list(X_trainT.columns)
important_features = pd.DataFrame(data=data, index=cols, columns=['coef']).sort_values('coef',ascending=False)

# %%
important_features.head(50)
# Out:
#                                           coef
# dayofweek_Tuesday                     1.159318
# TARGET_prevday                        1.030525
# IPDAILYpatients_daycase_deriv2_lag30  0.672669
# month_12                              0.604183
# dayofweek_Wednesday                   0.487967
# IPDAILYpatients_nonelec_deriv1_lag3   0.471232
# IPDAILYpatients_nonelec_deriv1_lag7   0.447769
# EDDAILYadmissions                     0.426275
# TARGET_prevday_deriv1_lag5            0.356130
# month_3                               0.306164
# month_2                               0.270090
# TARGET_prevday_deriv1_lag7            0.248998
# dayofweek_Sunday                      0.241312
# TARGET_prevday_deriv2_lag2            0.223949
# IPDAILYpatients_nonelec_deriv1_lag2   0.220792
# month_11                              0.206271
# month_10                              0.204101
# IPDAILYpatients_daycase_deriv2_lag1   0.198490
# IPDAILYpatients_elec                  0.185759
# EDDAILYattendances                    0.139868
# EDDAILYage_mean                       0.135317
# IPDAILYpatients_nonelec_deriv1_lag1   0.122821
# IPDAILYpatients_nonelec_deriv1_lag30  0.119726
# TARGET_prevday_deriv2_lag1            0.114467
# IPDAILYpatients_nonelec_deriv1_lag14  0.102896
# TARGET_prevday_lag13                  0.097418
# month_5                               0.081866
# IPDAILYage_75plus_elecnonelec         0.055861
# TARGET_prevday_deriv1_lag3            0.025981
# IPDAILYage_mean_elecnonelec           0.007195
# TARGET_prevday_lag27                 -0.003797
# IPDAILYpatients_nonelec              -0.014638
# IPDAILYpatients_daycase_deriv1_lag1  -0.029659
# IPDAILYpatients_nonelec_deriv1_lag5  -0.051394
# TARGET_prevday_deriv2_lag14          -0.057641
# TARGET_prevday_deriv2_lag3           -0.066712
# TARGET_prevday_deriv2_lag30          -0.091011
# TARGET_prevday_lag6                  -0.092568
# flag_target_prevday                  -0.096648
# EDDAILYage_75plus                    -0.107018
# TARGET_prevday_deriv1_lag14          -0.115307
# TARGET_prevday_deriv1_lag30          -0.126626
# month_8                              -0.128631
# TARGET_prevday_deriv1_lag1           -0.148467
# month_7                              -0.185168
# IPDAILYpatients_nonelec_deriv2_lag30 -0.189036
# IPDAILYpatients_nonelec_deriv2_lag2  -0.196615
# month_4                              -0.212415
# IPDAILYpatients_nonelec_deriv2_lag1  -0.233281
# IPDAILYpatients_nonelec_deriv2_lag5  -0.244042

# %%
col_to_drop = list(important_features[(important_features["coef"] > -0.1) & (important_features["coef"] < 0.1)].index)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(class_weight='balanced', n_estimators=500)

grid = {'min_samples_split':[10],
        'max_depth':[5,10],
        'min_samples_leaf':[10,20],
        
       }
# grid = {'C':[0.1]}

grid_search = find_best_model(rf, grid, X_trainT, y_train, 'CV set')
# Out:
# CV MODEL RESULTS
# {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10}
#    mean_test_score  mean_train_score
# 3         0.437588          0.594327

# %%
data = grid_search.best_estimator_.feature_importances_
cols = list(X_trainT.columns)
important_features = pd.DataFrame(data=data, index=cols).sort_values(0,ascending=False)

# %%
important_features
# Out:
#                                              0
# TARGET_prevday                        0.074046
# IPDAILYpatients_daycase               0.071135
# IPDAILYpatients_daycase_deriv1_lag30  0.065517
# IPDAILYpatients_total                 0.057548
# EDDAILYadmissions                     0.035572
# TARGET_prevday_deriv1_lag30           0.033629
# IPDAILYpatients_elec                  0.033362
# TARGET_prevday_deriv1_lag3            0.032452
# TARGET_prevday_deriv1_lag1            0.029468
# TARGET_prevday_deriv1_lag2            0.029102
# TARGET_prevday_deriv1_lag14           0.027182
# TARGET_prevday_deriv1_lag7            0.027107
# IPDAILYpatients_nonelec_deriv1_lag5   0.025449
# TARGET_prevday_deriv2_lag3            0.024946
# IPDAILYpatients_daycase_deriv1_lag1   0.022604
# TARGET_prevday_lag6                   0.018346
# IPDAILYpatients_nonelec_deriv1_lag7   0.018123
# TARGET_prevday_lag13                  0.015849
# EDDAILYattendances                    0.014734
# flag_target_prevday                   0.014664
# IPDAILYpatients_nonelec_deriv2_lag3   0.014625
# IPDAILYpatients_daycase_deriv2_lag30  0.014537
# TARGET_prevday_lag27                  0.014527
# IPDAILYage_mean_elecnonelec           0.014160
# IPDAILYpatients_nonelec_deriv1_lag3   0.013158
# TARGET_prevday_deriv2_lag14           0.012988
# IPDAILYpatients_nonelec_deriv2_lag7   0.012847
# IPDAILYpatients_nonelec               0.012823
# TARGET_prevday_deriv2_lag5            0.012065
# TARGET_prevday_deriv1_lag5            0.011566
# ...                                        ...
# IPDAILYpatients_nonelec_deriv1_lag2   0.010610
# TARGET_prevday_deriv2_lag7            0.010562
# IPDAILYpatients_nonelec_deriv2_lag1   0.010200
# TARGET_prevday_deriv2_lag30           0.009928
# IPDAILYpatients_nonelec_deriv2_lag5   0.009388
# IPDAILYpatients_daycase_deriv2_lag1   0.008799
# IPDAILYage_75plus_elecnonelec         0.008676
# EDDAILYage_mean                       0.008513
# EDDAILYage_75plus                     0.008327
# IPDAILYpatients_nonelec_deriv2_lag30  0.007879
# IPDAILYpatients_nonelec_deriv2_lag14  0.007444
# year                                  0.003856
# dayofweek_Tuesday                     0.003604
# dayofweek_Thursday                    0.001823
# dayofweek_Sunday                      0.001718
# dayofweek_Monday                      0.001624
# month_6                               0.001115
# month_9                               0.000941
# month_10                              0.000767
# dayofweek_Friday                      0.000431
# month_1                               0.000318
# month_3                               0.000230
# month_12                              0.000151
# month_7                               0.000133
# month_5                               0.000112
# dayofweek_Saturday                    0.000061
# month_11                              0.000057
# month_8                               0.000047
# month_2                               0.000031
# month_4                               0.000009
#
# [67 rows x 1 columns]

# %%
important_list = list(important_features.iloc[0:20].index)

# %%
rf = RandomForestClassifier(class_weight='balanced', n_estimators=300)

grid = {'min_samples_split':[10],
        'max_depth':[5,10],
        'min_samples_leaf':[10,20],
        
       }
# grid = {'C':[0.1]}

grid_search = find_best_model(rf, grid, X_trainT[important_list], y_train, 'CV set')
# Out:
# CV MODEL RESULTS
# {'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#    mean_test_score  mean_train_score
# 0         0.450783          0.609108

# %%
break
# Out:
#   File "<ipython-input-39-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %% [markdown]
# NOTE: consider creating log for preprocessing information in order for repeatability in future.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', lgr, grid_search, 'Model uses all derivative features from previous day. in D2_daily_data_to_model_FULLPIPELINE.ipynb.')
# Out:
# Model logged.

# %%
from src.eval.eval_utils import save_model_to_log

save_model_to_log('./../../data/output/model_log.pkl', 'D2', rf, grid_search, 'Model uses all derivative features from previous day. in D2_daily_data_to_model_FULLPIPELINE.ipynb.')
# Out:
# Model logged.

# %%
models = pd.read_pickle('./../../data/output/model_log.pkl')
# models.drop(3,inplace=True)
models
# Out:
#   dataV                                              model  \
# 0    v1  LogisticRegression(C=0.3, class_weight='balanc...
# 1    v1  (DecisionTreeClassifier(class_weight=None, cri...
# 2    v1  XGBClassifier(base_score=0.5, booster='gbtree'...
# 3    D2  RandomForestClassifier(bootstrap=True, class_w...
# 4    D2  LogisticRegression(C=1.0, class_weight='balanc...
#
#                                           gridsearch mean_train mean_valid  \
# 0     mean_fit_time  std_fit_time  mean_score_tim...    [0.629]     [0.52]
# 1      mean_fit_time  std_fit_time  mean_score_ti...    [0.685]    [0.419]
# 2     mean_fit_time  std_fit_time  mean_score_tim...    [0.829]    [0.439]
# 3     mean_fit_time  std_fit_time  mean_score_tim...     [0.64]    [0.454]
# 4      mean_fit_time  std_fit_time  mean_score_ti...    [0.489]    [0.445]
#
#                                                notes
# 0  Initial model which was built on first edition...
# 1                 Random Forest 1st attempt with v1.
# 2  V1 attempt with XGBOOST. KFOLD selection of fe...
# 3  Model uses all derivative features from previo...
# 4  Model uses all derivative features from previo...

# %%
models.to_pickle('./../../data/output/model_log.pkl')
