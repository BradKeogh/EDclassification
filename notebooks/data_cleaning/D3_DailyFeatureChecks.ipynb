# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# # ED

# %%
EDmorn = pd.read_pickle('./../../data/interim/D3_dailyTS/EDmorn.pkl')

# %%
EDmorn.head()
# Out:
#            EDMORNoccupancy EDMORNage_mean EDMORNage_75plus
# 2009-04-01              12        39.9167                1
# 2009-04-02              23        51.2174                3
# 2009-04-03              21        51.2381                5
# 2009-04-04              24        46.7083                6
# 2009-04-05              26        41.5385                3

# %%
EDmorn.plot(figsize=(18,6))

# %%
EDpday = pd.read_pickle('./../../data/interim/D3_dailyTS/EDprevday_summary.pkl')

# %%
EDpday.plot(figsize=(18,6))

# %% [markdown]
# # IP

# %%
IPmorn = pd.read_pickle('./../../data/interim/D3_dailyTS/IPmorn.pkl')

# %%
IPmorn.plot(figsize=(24,5))

# %%
IPmorn.tail()
# Out:
#            IPMORNpatients_total IPMORNpatients_nonelec IPMORNpatients_elec  \
# 2018-09-26                 1292                   1034                 248
# 2018-09-27                 1264                    993                 265
# 2018-09-28                 1261                    976                 271
# 2018-09-29                 1245                    975                 259
# 2018-09-30                 1213                    986                 213
#
#            IPMORNpatients_daycase IPMORNage_mean_elecnonelec  \
# 2018-09-26                     10                    60.6006
# 2018-09-27                      6                    60.8133
# 2018-09-28                     14                     60.456
# 2018-09-29                     11                    60.6201
# 2018-09-30                     14                    60.6307
#
#            IPMORNage_75plus_elecnonelec IPMORNwardmoves_mean_elecnonelec  \
# ...

# %%
IPpday = pd.read_pickle('./../../data/interim/D3_dailyTS/IPprevday_summary.pkl')

# %%
IPpday.plot(figsize=(18,6))

# %%
IPpday.head()
# Out:
#            IPDAILYpatients_total IPDAILYpatients_nonelec IPDAILYpatients_elec  \
# 2009-04-01                   NaN                     NaN                  NaN
# 2009-04-02                   410                     103                   81
# 2009-04-03                   579                     211                  144
# 2009-04-04                   663                     286                  144
# 2009-04-05                   497                     324                  104
#
#            IPDAILYpatients_daycase IPDAILYage_mean_elecnonelec  \
# 2009-04-01                     NaN                         NaN
# 2009-04-02                     226                      47.878
# 2009-04-03                     224                     51.0933
# 2009-04-04                     233                     50.2428
# 2009-04-05                      69                     50.0604
#
#            IPDAILYage_75plus_elecnonelec
# 2009-04-01                           NaN
# ...

# %% [markdown]
# #### look for which dates the christmas holiday decant happens

# %%
df = IPpday
start = pd.datetime(2017,12,1)
end = pd.datetime(2018,1,30)
dff = df[(df.index > start) & (df.index < end)]

dff.plot(figsize=(18,6))

# %%
df = IPpday
start = pd.datetime(2016,12,1)
end = pd.datetime(2017,1,30)
dff = df[(df.index > start) & (df.index < end)]

dff.plot(figsize=(18,6))

# %%
df = IPpday
start = pd.datetime(2015,12,1)
end = pd.datetime(2016,1,30)
dff = df[(df.index > start) & (df.index < end)]

dff.plot(figsize=(18,6))

# %%
df = IPpday
start = pd.datetime(2014,12,1)
end = pd.datetime(2015,1,30)
dff = df[(df.index > start) & (df.index < end)]

dff.plot(figsize=(18,6))

# %%
df = IPpday
start = pd.datetime(2013,12,1)
end = pd.datetime(2014,1,30)
dff = df[(df.index > start) & (df.index < end)]

dff.plot(figsize=(18,6))

# %% [markdown]
# Look like it is 23dec to 2nd/3rd Jan?
