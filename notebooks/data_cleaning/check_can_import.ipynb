# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('./../../../3_Data/EDclassification/WAC_UHS_EDexport_0918_rr.txt',low_memory=False)

# %%
df.head()
# Out:
#   Pseudo Patient Number  ATTENDANCE_NUMBER   Age Gender Department  \
# 0          004101045105        90902325901  94.0      F    Main ED
# 1          644868441371        90902326101  47.0      M    Main ED
# 2          668666687357        90902326501   0.0      M    Main ED
# 3          446747461391        90902328601   4.0      M    Main ED
# 4          423646238168        90902328801  31.0      F    Main ED
#
#   Site attended          Arrival Arrival mode        Arrival mode desc  \
# 0       Main ED  13-APR-09 09:16          NaN  BROUGHT IN BY AMBULANCE
# 1       Main ED  13-APR-09 09:22          NaN  BROUGHT IN BY AMBULANCE
# 2       Main ED  13-APR-09 09:31          NaN                    OTHER
# 3       Main ED  13-APR-09 10:52          NaN                    OTHER
# 4       Main ED  13-APR-09 11:18          NaN  BROUGHT IN BY AMBULANCE
#
#   1st time triaged [datetime] 1st time seen by doctor  \
# 0                         NaN         13-APR-09 10:28
# ...

# %%
IP  = pd.read_csv('./../../../3_Data/EDclassification/WAC_UHS_FCETable1_0918_rr_BK.txt',low_memory=False)

# %%
IP.head()
# Out:
#   Pseudo Patient Number  Age at  Admission  Gender  Spell Number  \
# 0          508656089369                 10       1       8673622
# 1          368636689369                  0       2       8672974
# 2          518050189349                 41       1       8663608
# 3          518050189349                 41       1       8663608
# 4          518050189349                 41       1       8663608
#
#     Admission Date   Discharge Date Admission Method Code  \
# 0  18-JUN-09 13:15  18-JUN-09 18:00                    21
# 1  18-JUN-09 04:03  19-JUN-09 11:49                    82
# 2  02-JUN-09 12:45  04-JUN-09 10:30                    21
# 3  02-JUN-09 12:45  04-JUN-09 10:30                    21
# 4  02-JUN-09 12:45  04-JUN-09 10:30                    21
#
#   Admission Method Description  Length of Stay (Days)  Admission Source Code  \
# 0                EMERGENCY A+E                      0                     19
# ...

# %%
IP2  = pd.read_csv('./../../../3_Data/EDclassification/WAC_UHS_FCETable2_0918_rr.txt',low_memory=False)

# %%
IP2.head()
# Out:
#    Spell Number  Ward Code Ward Code Description Ward Stay Start (Date)  \
# 0       8670648       1146      AMU ADMISSIONS 2    15/06/2009 04:00:00
# 1       8670648       1145      AMU ADMISSIONS 1    16/06/2009 11:34:02
# 2       8670648        151            D8 KENNETT    17/06/2009 22:00:02
# 3       8670696        129        G3 PAEDIATRICS    22/06/2009 08:00:00
# 4       8670732       1169  D3H HAMILTON FAIRLEY    15/06/2009 09:00:00
#
#   Ward Stay End (Date)
# 0  16/06/2009 11:34:02
# 1  17/06/2009 22:00:02
# 2  24/06/2009 10:59:00
# 3  23/06/2009 09:46:00
# 4  19/06/2009 14:32:00
